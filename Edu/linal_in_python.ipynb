# %%
import pandas as pd
import numpy as np

# %%
a = np.array([1, 2, 3])
a, type(a)
# Out:
# (array([1, 2, 3]), numpy.ndarray)

# %%
Hut_Paradise_DF = pd.DataFrame({
    '1.Rent': [65, 70, 120, 35, 40, 50, 100, 90, 85], 
    '2.Area': [50, 52, 80, 33, 33, 44, 80, 65, 65], 
    '3.Rooms':[3, 2, 1, 1, 1, 2, 4, 3, 2],
    '4.Floor':[5, 12, 10, 3, 6, 13, 8, 21, 5], 
    '5.Demo two weeks':[8, 4, 5, 10, 20, 12, 5, 1, 10], 
    '6.Liv.Area': [37, 40, 65, 20, 16, 35, 60, 50, 40]
})
Hut_Paradise_DF
# Out:
#    1.Rent  2.Area  3.Rooms  4.Floor  5.Demo two weeks  6.Liv.Area
# 0      65      50        3        5                 8          37
# 1      70      52        2       12                 4          40
# 2     120      80        1       10                 5          65
# 3      35      33        1        3                10          20
# 4      40      33        1        6                20          16
# 5      50      44        2       13                12          35
# 6     100      80        4        8                 5          60
# 7      90      65        3       21                 1          50
# 8      85      65        2        5                10          40

# %%
A = Hut_Paradise_DF.values
A
# Out:
# array([[ 65,  50,   3,   5,   8,  37],
#        [ 70,  52,   2,  12,   4,  40],
#        [120,  80,   1,  10,   5,  65],
#        [ 35,  33,   1,   3,  10,  20],
#        [ 40,  33,   1,   6,  20,  16],
#        [ 50,  44,   2,  13,  12,  35],
#        [100,  80,   4,   8,   5,  60],
#        [ 90,  65,   3,  21,   1,  50],
#        [ 85,  65,   2,   5,  10,  40]], dtype=int64)

# %%
hut_1 = A[0]
rent = A[:, 0]
hut_1, rent, rent[6], rent[2]
# Out:
# (array([65, 50,  3,  5,  8, 37], dtype=int64),
#  array([ 65,  70, 120,  35,  40,  50, 100,  90,  85], dtype=int64),
#  100,
#  120)

# %%
Hut_Paradise_values = Hut_Paradise_DF.values
Hut_Paradise_values
# Out:
# array([[ 65,  50,   3,   5,   8,  37],
#        [ 70,  52,   2,  12,   4,  40],
#        [120,  80,   1,  10,   5,  65],
#        [ 35,  33,   1,   3,  10,  20],
#        [ 40,  33,   1,   6,  20,  16],
#        [ 50,  44,   2,  13,  12,  35],
#        [100,  80,   4,   8,   5,  60],
#        [ 90,  65,   3,  21,   1,  50],
#        [ 85,  65,   2,   5,  10,  40]], dtype=int64)
