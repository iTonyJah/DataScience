# %%
from sympy import FiniteSet, Union

# %%
l1 = [1, 3, 7, 10] 
l2 = [9, 7, 1] 
a = FiniteSet(*l1) 
b = FiniteSet(*l2) 
Union(a, b)
# Out:
# {1, 3, 7, 9, 10}

# %%
from sympy import ConditionSet, Eq, Symbol, Interval
x = Symbol('x')
s = ConditionSet(x, Eq(x**2 - 5*x, 0), Interval(2, 9))
s
# Out:
# ConditionSet(x, Eq(x**2 - 5*x, 0), Interval(2, 9))

# %%
from sympy import *

x = symbols('x')
f = 2*x + 1
plot(f)

# %%
x = symbols('x')
f = x**2 + 1
plot(f)

# %%
from sympy import *
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %%
summation = sum(2*i for i in range(1,6))
print(summation)
# Out:
# 30

# %%
x = symbols('x')
expr = x**2 / x**5
print(expr) # x**(-3)
# Out:
# x**(-3)

# %%
x = symbols('x')
expr = (1-x)*(-4-x)*(12-x)+3*9*13+5*4*7-13*(-4-x)-7*9*(1-x)-(12-x)*4*3
print(expr) # x**(-3)
# Out:
# 88*x + (1 - x)*(12 - x)*(-x - 4) + 336

# %%
x = symbols('x')
f = 1 / x
result = limit(f, x, oo)
print(result) # 0
# Out:
# 0

# %%
n = symbols('n')
f = (1 + (1/n))**n
result = limit(f, n, oo)
print(result) # E
print(result.evalf()) # 2.71828182845905
# Out:
# E
# 2.71828182845905

# %% [markdown]
# Пример 1.18. Вычисление производной с помощью SymPy

# %%
# Объявляем символ 'x' для SymPy
x = symbols('x')
# Теперь объявляем функцию через обычный синтаксис Python
f = x**2
# Вычисляем производную функции
dx_f = diff(f)
print(dx_f) # выводит 2*x
# Out:
# 2*x

# %% [markdown]
# Пример 1.21. Вычисление частных производных с помощью SymPy

# %%
from sympy import *
from sympy.plotting import plot3d

# Объявляем символы x и y в SymPy
x,y = symbols('x y')

# Теперь объявляем функцию через обычный синтаксис Python
f = 2*x**3 + 3*y**3

# Вычисляем частные производные по x и y
dx_f = diff(f, x)
dy_f = diff(f, y)

print(dx_f) # выводит 6*x**2
print(dy_f) # выводит 9*y**2

# Выводим график функции
plot3d(f)
# Out:
# 6*x**2
# 9*y**2

# %%
expression = (sqrt(13)+sqrt(7))**2/(10+sqrt(91))
expression
# Out:
# (sqrt(7) + sqrt(13))**2/(sqrt(91) + 10)

# %%
simplify(expression) # функция simplify выполняет упрощение выражений
# Out:
# 2

# %%
a = Symbol('a')
expression_a = 2 * a * a**(4/3) * 3 * a**(2/3)
expression_a
# Out:
# 6*a**3.0

# %%
x = Symbol('x')

# %%
expression_g = (4*x-x*x)**Rational(1,3)
expression_g
# Out:
# (-x**2 + 4*x)**(1/3)

# %%
expression_g = (4*x-x*x)**(1/3)
expression_g
# Out:
# (-x**2 + 4*x)**0.333333333333333

# %%
expression_g = simplify(expression_g)
expression_g
# Out:
# (x*(4 - x))**0.333333333333333

# %% [raw]
# Комнаты	Площадь	Этаж	Центр	Спальный 1	Спальный 2	Цена
# 3	51	3	0	1	0	2200
# 1	30	1	0	1	0	1600
# 2	45	2	0	1	0	1900
# 3	55	1	0	1	0	2000
# 1	45	3	1	0	0	4500

# %%
x1_1, x1_2, x1_3, x1_4, x1_5 = symbols('x1_1 x1_2 x1_3 x1_4 x1_5')

# %%
x1_1, x1_2, x1_3, x1_4, x1_5 = 3, 1, 2, 3, 1
x1_mean = (x1_1 + x1_2 + x1_3 + x1_4 + x1_5) / 5
x1_mean
# Out:
# 2.0

# %%
x1_1, x1_2, x1_3, x1_4, x1_5 = 51, 30, 45, 55, 45
x1_mean = (x1_1 + x1_2 + x1_3 + x1_4 + x1_5) / 5
x1_mean_str = str(x1_mean)
x1_mean, x1_mean_str, Rational(x1_mean_str)
# Out:
# (45.2, '45.2', 226/5)

# %%
x1_1cent = x1_1 - Rational(x1_mean_str)
x1_2cent = x1_2 - Rational(x1_mean_str)
x1_3cent = x1_3 - Rational(x1_mean_str)
x1_4cent = x1_4 - Rational(x1_mean_str)
x1_5cent = x1_5 - Rational(x1_mean_str)
x1_1cent, x1_2cent, x1_3cent, x1_4cent, x1_5cent
# Out:
# (29/5, -76/5, -1/5, 49/5, -1/5)

# %%
x1_len = (x1_1cent**2 + x1_2cent**2 + x1_3cent**2 + x1_4cent**2 + x1_5cent**2)**Rational(1,2)
x1_len
# Out:
# 2*sqrt(2255)/5

# %%
programmers ={
'bennet@xyz.com',
'darcy@abc.com',
'margaret@xyz.com',
'pa@hhh.com',
'marimari@xyz.com',
'mallika@yahoo.com',
'abc@xyz.com',
'0071235@gmail.ru',
}

machine_learners = {
'marimari@xyz.com',
'darcy@abc.com',
'0071235@gmail.ru',
'darcy@abc.com',
'petr44@xyz.com',
'katrin@ya.com',
}

# %%
len(programmers | machine_learners), len(programmers), len(machine_learners)
# Out:
# (10, 8, 5)

# %%
len(programmers & machine_learners)
# Out:
# 3

# %%
len((programmers | machine_learners) - (programmers & machine_learners))
# Out:
# 7

# %%
programmers ^ machine_learners, len(programmers ^ machine_learners)
# Out:
# ({'abc@xyz.com',
#   'bennet@xyz.com',
#   'katrin@ya.com',
#   'mallika@yahoo.com',
#   'margaret@xyz.com',
#   'pa@hhh.com',
#   'petr44@xyz.com'},
#  7)
