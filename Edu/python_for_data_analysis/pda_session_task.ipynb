# %%
# Импортируем библиотеки
# стандартные
import os
import re
import pandas as pd
import numpy as np
import gdown

# локальная библиотека (приложена)
from gdrivedl import get_download_link

# %% [markdown]
# # 1/7   Постановка задачи

# %% [markdown]
# ✍ Настало время попробовать свои силы в реальном Data Science-проекте. Вам предстоит решить часть настоящей бизнес-задачи и примерить роль аналитика в компании *HeadHunter*. Проект станет новым этапом сбора вашего портфолио на *GitHub*, которым вы сможете похвастаться перед работодателем!

# %% [markdown]
# **Описание задачи**
#
# В вашем распоряжении будет база резюме, выгруженная с сайта поиска вакансий *hh.ru*.
#
# Файл с исходными данными вы можете скачать здесь.

# %%
sf_link = 'https://drive.google.com/file/d/1Kb78mAWYKcYlellTGhIjPI-bCcKbGuTn/view?usp=sharing'
# резервная копия
my_link = 'https://drive.google.com/file/d/1ZKODYp54UGoJ4qZli7_fn6Duid4w-1C0/view?usp=drive_link'
local_path = 'dst-3.0_16_1_hh_database.csv'

# cписок ссылок для преобразования
links = [
    sf_link,
    my_link,
]

for i, url in enumerate(links):
    links[i] = get_download_link(url)

links.append(local_path)

# Определяем путь для временного сохранения файла
output_path = 'gdown_temp/temp_downloaded_file.csv'

# %%
gdown.download(links[0], output_path, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=view&id=1Kb78mAWYKcYlellTGhIjPI-bCcKbGuTn&confirm=t
# To: C:\Users\iTonyJah\DataScience\Edu\python_for_data_analysis\gdown_temp\temp_downloaded_file.csv
# 100%|███████████████████████████████████████████████████████████████████████████████| 455M/455M [00:12<00:00, 36.7MB/s]
# 'gdown_temp/temp_downloaded_file.csv'

# %%
data = pd.read_csv(output_path, sep=';')

data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...
