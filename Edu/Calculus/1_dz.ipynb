# %% [markdown]
# # Домашнее задание
#
# Студента Лысогора А.А.

# %% [markdown]
# Математический анализ
# 69 баллов

# %% [markdown]
# # **Задача 1** (14 баллов)
#
# Найдите экстремумы функции:

# %% [markdown]
# $$
# f(x, y, z)=2 x^3+2 x y+2 x z+y^2+z^2+2 y-8 .
# $$

# %% [markdown]
# Распишите подробное решение.

# %% [markdown]
# ![частные производные первого порядкка](1_dz_1_1.jpg)

# %% [markdown]
# $f'x = 6x^2 + 2y + 2z$
#
# $f'y = 2x + 2y + 2$
#
# $f'z = 2x + 2$
#
# $P_1 = (1,−2,−1)$,
# $P_2 = (-\frac{1}{3},-\frac{2}{3},\frac{1}{3})$

# %% [markdown]
# ![частные производные второго порядка](1_dz_1_2.jpg)

# %% [markdown]
# $P_1 = (1,−2,−1)$ - локальный минимум
#
# $P_2 = (-\frac{1}{3},-\frac{2}{3},\frac{1}{3})$ - седловая точка

# %% [markdown]
# $
# f(x, y, z)=2 x^3+2 x y+2 x z+y^2+z^2+2 y-8
# $
#
# $
# f(1, -2, -1)=2 \cdot (1)^3+2 \cdot 1 \cdot (-2) + 2 \cdot 1 \cdot (-1) + (-2)^2+(-1)^2+2 \cdot (-2)-8
# = 2 - 4 - 2 + 4 + 1 - 4 - 8 = -11
# $

# %% [markdown]
# **Ответ:** $P_1 = (1,−2,−1)$ $-$ локальный минимум (локальный, так как функция может принимать и более минимальные значения при $x$ стремящимся к минус бесконечности.
#
# $f(1, -2, -1)= -11$, значение функции в этой точке

# %% [markdown]
# # **Задача 2** (25 баллов)
#
# Найдите условные экстремумы функции:

# %% [markdown]
# $
# f(x, y)=4 x+8 y, y^2-2 x y+5=0
# $

# %% [markdown]
# Вычислите результат самостоятельно (вручную) и с помощью Python. Сравните результаты.

# %%
from sympy import *
a, b, w=symbols('a b w' )

g = 4*a + 8*b
print('Целевая функция для аргументов a и b :\n f = ', g)

q = b**2 - 2*a*b + 5
print('Функция ограничений: ', q,'= 0')

f = 4*a + 8*b + w * (b**2 - 2*a*b + 5)
print('Функция Лагранжа :\n ',f)

fa = f.diff(a)
print('df/da =',fa,'= 0')

fb = f.diff(b)
print('df/db =',fb,'= 0')

fw = f.diff(w)
print('df/dw =',fw,'= 0')

sols = solve([fa, fb, fw], (a, b, w), dict=True)
print('Стационарная точка M(x,y)_1:\n',float(sols[0][a]),',',float(sols[0][b]))
print('Стационарная точка M(x,y)_2:\n',float(sols[1][a]),',',float(sols[1][b]))
# Out:
# Целевая функция для аргументов a и b :
#  f =  4*a + 8*b
# Функция ограничений:  -2*a*b + b**2 + 5 = 0
# Функция Лагранжа :
#   4*a + 8*b + w*(-2*a*b + b**2 + 5)
# df/da = -2*b*w + 4 = 0
# df/db = w*(-2*a + 2*b) + 8 = 0
# df/dw = -2*a*b + b**2 + 5 = 0
# Стационарная точка M(x,y)_1:
#  -3.0 , -1.0
# Стационарная точка M(x,y)_2:
#  3.0 , 1.0

# %% [markdown]
# # **Задача 3** (30 баллов)
#
# Вам предложены данные с информацией о успеваемости студентов:
#
# Независимые переменные:
# * Hours Studied: Общее количество часов, потраченных на учебу каждым студентом.
# * Previous Scores: Баллы, полученные студентами на предыдущих экзаменах.
# * Sleep Hours: Среднее количество часов сна студента в сутки.
# * Sample Question Papers Practiced: Количество пробных экзаменационных работ, с которыми студент занимался.
#
# Целевая переменная:
# * Performance Index: Показатель общей успеваемости каждого студента. Индекс успеваемости отражает академическую успеваемость студента и округляется до ближайшего целого числа. Индекс варьируется от 10 до 100, при этом более высокие значения свидетельствуют о более высокой успеваемости.

# %% [markdown]
# **Решите задачу линейной регрессии, реализовав градиентный спуск самостоятельно, не используя готовое решение из какой-либо библиотеки.**

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Student_Performance.txt')

df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
X = df[['Hours Studied', 'Previous Scores', 'Sleep Hours', 'Sample Question Papers Practiced']].values

y = df['Performance Index']
n = len(y)
X = np.append(np.ones((n, 1)), X, axis = 1)

y = df['Performance Index'].values.reshape(n, 1)

# %%
par = np.zeros((5, 1)) + 5

# %%
par
# Out:
# array([[5.],
#        [5.],
#        [5.],
#        [5.],
#        [5.]])

# %%
def performance_index(X, y, par):
    y_pred = np.dot(X, par)
    error = (y_pred - y)**2
    perfect = 100/n*np.sum(error) - 10/n*np.sum(error)
    return perfect


def grad_d(X, y, par, alpha, iterations):
    perf_ind = []
    for i in range(iterations):
        y_pred = np.dot(X, par)
        der = np.dot (X.transpose(), (y_pred - y))/ n
        par -= alpha * der
        perf_ind.append(performance_index(X, y, par))

        if i % 100_000 == 0:
            print(f"iter={i}", par[0], par[1], par[2], par[3], par[4])

    print(f"iter={i}", par[0], par[1], par[2], par[3], par[4])    
    return par, perf_ind

# %%
step = 0.000384
iter = 2_300_000

# %%
par, perf_opt = grad_d(X, y, par, step, iter)
# Out:
# iter=0 [4.85502552] [4.27123293] [-5.52823602] [4.04792684] [4.31963041]
# iter=100000 [-19.84420443] [2.57724555] [0.93430259] [-0.35534759] [0.00089901]
# iter=200000 [-28.69152786] [2.75278946] [0.98787318] [0.1732732] [0.12439676]
# iter=300000 [-31.91544456] [2.81675664] [1.00739285] [0.36589964] [0.1693986]
# iter=400000 [-33.09022232] [2.84006593] [1.01450571] [0.43609167] [0.18579703]
# iter=500000 [-33.51830497] [2.8485597] [1.0170976] [0.46166927] [0.19177253]
# iter=600000 [-33.67429597] [2.85165479] [1.01804207] [0.4709896] [0.19394996]
# iter=700000 [-33.73113824] [2.85278262] [1.01838623] [0.47438588] [0.19474341]
# iter=800000 [-33.75185125] [2.8531936] [1.01851164] [0.47562347] [0.19503254]
# iter=900000 [-33.75939896] [2.85334336] [1.01855734] [0.47607444] [0.1951379]
# iter=1000000 [-33.76214931] [2.85339793] [1.01857399] [0.47623877] [0.19517629]
# iter=1100000 [-33.76315152] [2.85341781] [1.01858006] [0.47629865] [0.19519028]
# iter=1200000 [-33.76351672] [2.85342506] [1.01858227] [0.47632047] [0.19519537]
# iter=1300000 [-33.7636498] [2.8534277] [1.01858308] [0.47632842] [0.19519723]
# iter=1400000 [-33.76369829] [2.85342866] [1.01858337] [0.47633132] [0.19519791]
# iter=1500000 [-33.76371596] [2.85342901] [1.01858348] [0.47633238] [0.19519816]
# iter=1600000 [-33.7637224] [2.85342914] [1.01858352] [0.47633276] [0.19519825]
# iter=1700000 [-33.76372475] [2.85342919] [1.01858353] [0.4763329] [0.19519828]
# iter=1800000 [-33.7637256] [2.8534292] [1.01858354] [0.47633295] [0.19519829]
# iter=1900000 [-33.76372591] [2.85342921] [1.01858354] [0.47633297] [0.19519829]
# iter=2000000 [-33.76372603] [2.85342921] [1.01858354] [0.47633298] [0.1951983]
# iter=2100000 [-33.76372607] [2.85342921] [1.01858354] [0.47633298] [0.1951983]
# iter=2200000 [-33.76372608] [2.85342921] [1.01858354] [0.47633298] [0.1951983]
# iter=2299999 [-33.76372609] [2.85342921] [1.01858354] [0.47633298] [0.1951983]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [[0.         2.85342921 1.01858354 0.47633298 0.1951983 ]]
# [-33.76372609]

# %%
par
# Out:
# array([[-33.76372609],
#        [  2.85342921],
#        [  1.01858354],
#        [  0.47633298],
#        [  0.1951983 ]])

# %%
import numpy as np
import statsmodels.api as sm
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                 2.147e+05
# Date:                Sun, 26 Oct 2025   Prob (F-statistic):               0.00
# Time:                        21:54:30   Log-Likelihood:                -21418.
# No. Observations:               10000   AIC:                         4.285e+04
# Df Residuals:                    9995   BIC:                         4.288e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -33.7637      0.127   -266.189      0.000     -34.012     -33.515
# x1             2.8534      0.008    358.403      0.000       2.838       2.869
# x2             1.0186      0.001    857.021      0.000       1.016       1.021
# x3             0.4763      0.012     39.193      0.000       0.453       0.500
# x4             0.1952      0.007     27.152      0.000       0.181       0.209
# ==============================================================================
# Omnibus:                        1.962   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.375   Jarque-Bera (JB):                1.977
# Skew:                           0.009   Prob(JB):                        0.372
# Kurtosis:                       3.067   Cond. No.                         445.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
