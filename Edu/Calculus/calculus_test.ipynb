# %% [markdown]
# $f(x_1, x_2, x_3) = \frac{1}{1 + e^{-2(x_1 + x_2 + x_3)}}$

# %%
from sympy import Symbol, S, symbols
from sympy.calculus.util import function_range
x, x1, x2, x3 = symbols('x x1 x2 x3')
x = x1 + x2 + x3
f = 1 / (1 + exp(-2 * (x)) )
f1 = 1 / (1 + exp(-2 * (x1)) )
function_range(f, x, S.Reals)
# Out:
# {1/(1 + exp(-2*x1)*exp(-2*x2)*exp(-2*x3))}

# %%
f
# Out:
# 1/(exp(-2*x1 - 2*x2 - 2*x3) + 1)

# %%
function_range(f1, x1, S.Reals)
# Out:
# Interval.open(0, 1)

# %%
substitutions = {x1: 1, x2: 1, x3: 0}
f.subs(substitutions)
# Out:
# 1/(exp(-4) + 1)

# %%
f.subs(substitutions).evalf()
# Out:
# 0.982013790037908

# %%
subs_dict2 = {x1: 0.1, x2: 0.3, x3: 0.6}
f.subs(subs_dict2)
# Out:
# 0.880797077977883

# %%
from sympy import symbols, cos, diff

a, b, c = symbols('a b c', real=True)
f = 5*a*b - a*cos(c) + a**8 + c**2*b

print(diff(f, a))
# Out:
# 8*a**7 + 5*b - cos(c)

# %% [markdown]
# $f(x,y) = x^2 − y^2$

# %%
from sympy import symbols, plot
from sympy.plotting import plot3d
x, y = symbols('x y')
f = x**2 - y**2
plot3d(f)

# %% [markdown]
# $f(a,b) = (5 − a − 2b)^2$

# %%
from sympy import symbols, plot
from sympy.plotting import plot3d
x, y = symbols('x y')
f = (5 - x - 2*y)**2
plot3d(f)

# %% [markdown]
# $u = x^2 + 3xy + 4y^2$

# %%
from sympy import symbols, plot
from sympy.plotting import plot3d
x, y = symbols('x y')
f = x**2 + 3*x*y + 4*y**2
plot3d(f)

# %%
diff(f, x)
# Out:
# 2*x + 3*y

# %%
diff(f, y)
# Out:
# 3*x + 8*y

# %% [markdown]
# $u = y \ sin \ x + sin \ y$

# %%
from sympy import symbols, plot, sin, cos
from sympy.plotting import plot3d
f = y * sin(x) + sin(y)
plot3d(f)

# %%
from sympy import Symbol, S, sin #импортируем нужные функции для обозначения переменных
from sympy.calculus.util import function_range #импортируем функцию для поиска области значений
x = Symbol("x")
f = sin(x)
function_range(f, x, S.Reals)
# Out:
# Interval(-1, 1)

# %% [markdown]
# $\displaystyle \left[-1, 1\right]$

# %% [markdown]
# Или для более сложной функции:
# $f(x) = \frac{x^2 - 3}{e^x}$

# %%
from sympy import Symbol, S #импортируем нужные функции для обозначения переменных
from sympy.calculus.util import function_range #импортируем функцию для поиска области значений
from sympy import exp #добавляем функцию для вычисления экспоненциальной функции
x = Symbol("x")
f = (x*x-3)/(exp(x))
function_range(f, x, S.Reals)
# Out:
# Interval(-2*E, oo)

# %% [markdown]
# $\displaystyle \left[- 2 e, \infty\right)$

# %% [markdown]
# Чётные нечётные

# %% [markdown]
# $f(x) = x^2 - x$
#
# $f(-x) = (-x)^2 + x = x^2 + x$
#
# ни чётная, ни нечётная

# %%
from sympy import *

x = symbols('x')
f = x**2 + x
plot(f)

# %% [markdown]
# $y = x^2 + 2x - 8$

# %%
x = symbols('x')
f = x**2 + 2*x -8
plot(f)

# %%
from sympy import symbols, solve

# 1. Определяем символьную переменную
x = symbols('x')

# 2. Решаем уравнение
solutions = solve(x**2 + 2*x - 8, x)

# Выводим результат
print(solutions)
# Out:
# [-4, 2]

# %% [markdown]
# Найдите область значений для функции
# $f(x) = \frac{3}{x^2 - 10}$

# %%
from sympy import Symbol, S #импортируем нужные функции для обозначения переменных
from sympy.calculus.util import function_range #импортируем функцию для поиска области значений
from sympy import exp #добавляем функцию для вычисления экспоненциальной функции
x = Symbol("x")
f = (3)/(x**2 - 10)
function_range(f, x, S.Reals)
# Out:
# Union(Interval(-oo, -3/10), Interval.open(0, oo))

# %% [markdown]
# # Производная / Derivative

# %% [markdown]
# Вычислить производную для функции $f(x) = x^4 +3x^3+4x^2+8$

# %%
import sympy
x = sympy.Symbol('x')
expr = x**4 + 3*x**3 + 4*x**2 + 8
expr.diff(x)
# Out:
# 4*x**3 + 9*x**2 + 8*x

# %% [markdown]
# Вычислить производную для функции $f(x) = ln(x^2 + 5x) + e^{sin(x)}$

# %%
import sympy
from sympy import diff, sin, exp, log, Symbol
x = Symbol('x')
expr = log(x**2 + 5*x) + exp(sin(x))
expr.diff()
# Out:
# (2*x + 5)/(x**2 + 5*x) + exp(sin(x))*cos(x)

# %% [markdown]
# С помощью библиотеки SymPy найдите производную для функции
# $y = sin(3x + log(x))\cdot e^x$

# %%
from sympy import Symbol, log, sin, exp, diff
x = Symbol('x')
expr = sin(3*x + log(x)) * exp(x)
expr.diff(x)
# Out:
# (3 + 1/x)*exp(x)*cos(3*x + log(x)) + exp(x)*sin(3*x + log(x))

# %% [markdown]
# Найдите точку минимума для функции $y = -\frac{x^2 + 1}{x}$

# %%
from sympy import *
x = Symbol('x')
expr = -((x**2 + 1) / (x))
expr
# Out:
# -(x**2 + 1)/x

# %%
scale = 10
plot(expr, (x, -scale, scale), xlim=(-scale, scale), ylim=(-scale, scale))

# %%
diff(expr)
# Out:
# -2 + (x**2 + 1)/x**2

# %% [markdown]
# # Вычисление второй производной $f''(x)$

# %% [markdown]
# expr.diff(x, 2)

# %%
from sympy import Symbol, log, sin, exp, diff, plot
x = Symbol('x')

# %% [markdown]
# вычислить производную $sin^2 3x$

# %%
expr = sin(3*x)**2
expr.diff(x)
# Out:
# 6*sin(3*x)*cos(3*x)

# %%
expr = 3 * x**2 - 12*x + 1
plot(expr)

# %%
plot(expr.diff())

# %% [markdown]
# # Исследование функций

# %%
from sympy import Symbol, log, sin, exp, diff, plot, solve, symbols, Eq
x, y = symbols('x y')

# %%
func = 5*x**2 - 3*x + 100
plot(func)
