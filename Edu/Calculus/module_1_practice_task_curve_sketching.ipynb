# %% [markdown]
# # 8/11 самостоятельное задание

# %% [markdown]
# Исследуемая функция:
# $y = \frac{x^3}{2(x+5)^2}
# $

# %%
from sympy import plot, Symbol
x = Symbol("x") 
f = (x**3)/(2*(x+5)**2)

# %% [markdown]
# ## Область определения

# %%
from sympy import Symbol, S
from sympy.calculus.util import continuous_domain 
x = Symbol("x") 
continuous_domain(f, x, S.Reals)
# Out:
# Union(Interval.open(-oo, -5), Interval.open(-5, oo))

# %%
f
# Out:
# x**3/(2*(x + 5)**2)

# %% [markdown]
# ## Область значений функции

# %%
from sympy import Symbol, S
from sympy.calculus.util import function_range

function_range(f, x, S.Reals)
# Out:
# Interval(-oo, oo)

# %%
f
# Out:
# x**3/(2*(x + 5)**2)

# %% [markdown]
# ## Нахождение точек пересечения с осями координат

# %%
from sympy import solveset, Eq
solveset(Eq(f, 0), x)
# Out:
# {0}

# %%
f.subs(x, 0)
# Out:
# 0

# %% [markdown]
# ## Исследование функции на чётность и нечётность

# %% [markdown]
# $y(-x) = \frac{-x^3}{2(-x+5)^2}$
#
# функция ни чётная, ни нечётная

# %% [markdown]
# ## Нахождение производной

# %%
f
# Out:
# x**3/(2*(x + 5)**2)

# %%
f.diff(x)
# Out:
# -x**3/(x + 5)**3 + 3*x**2/(2*(x + 5)**2)

# %% [markdown]
# найдём точки, в которых она может менять знак

# %%
y = expr.diff(x)
solveset(Eq(y, 0), x)
# Out:
# {-15, 0}

# %%
y
# Out:
# -x**3/(x + 5)**3 + 3*x**2/(2*(x + 5)**2)

# %%
solveset(Eq(y,0),1)
# Out:
# {3*(x + 5)/(2*x)}

# %%
scale = 20
plot(y, (x, -scale, scale), xlim=(-scale, scale), ylim=(-scale, scale))

# %% [markdown]
# ## Нахождение второй производной

# %%
expr.diff(x,2)
# Out:
# 3*x*(x**2/(x + 5)**2 - 2*x/(x + 5) + 1)/(x + 5)**2

# %%
y = expr.diff(x,2)
solveset(Eq(y, 0), x)
# Out:
# {0}

# %% [markdown]
# ## Нахождение асимптот

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x**2-1)
limit(f,x,oo)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x**2-1)
limit(f,x,1)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x**2-1)
limit(f,x,-1)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/((x**2-1)*x)
limit(f,x,oo)
# Out:
# 1

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/((x**2-1)) - 1*x
limit(f,x,oo)
# Out:
# 0

# %% [markdown]
# ## построим график

# %%
from sympy import Symbol, limit, oo
from sympy import plot
x = Symbol("x")
scale = 2
plot(f, (x, -scale, scale), xlim=(-scale, scale), ylim=(-scale, scale))
