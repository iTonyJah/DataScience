# %% [markdown]
# # Практика к занятию : бэггинг и случайный лес
#
# **Что попробуем**:
#
# 1. Загрузим открытый датасет `diabetes` из `sklearn` (задача регрессии).
# 2. Реализуем простой бэггинг вручную (ансамбль деревьев решений с бутстрэпом).
# 3. Реализуем 'ручной' случайный лес (т.е. бэггинг + случайная подвыборка признаков для каждого дерева).
# 4. Сравним наши реализации с `BaggingRegressor` и `RandomForestRegressor` из `sklearn` по метрикам: RMSE, MAE, R2.
# 5. Оценим важности признаков (feature importances) для каждой модели.

# %%
from math import sqrt

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
def print_metrics(name, y_true, y_pred):
    # Функция для форматированного вывода метрик
    m = regression_metrics(y_true, y_pred)
    print(f"{name}: RMSE={m['RMSE']:.4f}, MAE={m['MAE']:.4f}, R2={m['R2']:.4f}")

def regression_metrics(y_true, y_pred):
    # метрики регрессии
    rmse = sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return {"RMSE": rmse, "MAE": mae, "R2": r2}

# %%
# Загрузка датасета и разделение на train/test
Xy = load_diabetes(as_frame=True)
df = Xy.frame.copy()
X = df.drop(columns=[Xy.target.name])
y = df[Xy.target.name]

# %%
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
type(X), type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
X.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
# Небольшая предобработка: стандартизируем признаки (полезно для визуализации и стабильности)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=28)

scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

print('Train size:', X_train.shape)
print('Test size:', X_test.shape)
# Out:
# Train size: (331, 10)
# Test size: (111, 10)

# %%
# Базовая модель: одиночное дерево решений
single_tree = DecisionTreeRegressor(random_state=0, min_samples_leaf=20)
single_tree.fit(X_train, y_train)

y_pred_tree_train = single_tree.predict(X_train)
print_metrics('DecisionTree train', y_train, y_pred_tree_train)

y_pred_tree_test = single_tree.predict(X_test)
print_metrics('DecisionTree test', y_test, y_pred_tree_test)
# Out:
# DecisionTree train: RMSE=50.4947, MAE=39.6377, R2=0.5591
# DecisionTree test: RMSE=66.7143, MAE=53.9284, R2=0.2990

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train, y_train)

y_pred_reg_train = reg.predict(X_train)
print_metrics('LinearRegression train', y_train, y_pred_reg_train)

y_pred_reg_test = reg.predict(X_test)
print_metrics('LinearRegression test', y_test, y_pred_reg_test)
# Out:
# LinearRegression train: RMSE=52.1821, MAE=41.5586, R2=0.5291
# LinearRegression test: RMSE=57.8129, MAE=48.3749, R2=0.4736

# %%
X_train.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
reg.coef_
# Out:
# array([  0.11919378, -10.95787292,  21.95363307,  18.50129689,
#        -36.57243021,  18.09272903,   8.91350274,  14.7707773 ,
#         34.77028001,   2.77916268])

# %%
y_train.min(), y_train.max()
# Out:
# (25.0, 341.0)

# %%
 73.4643 / (y_train.max() - y_train.min()) * 100
# Out:
# 23.24819620253164

# %% [markdown]
# ## Реализация Bagging вручную
#
# Идея: обучить N деревьев на бутстрэп-выборках (sample with replacement) и усреднить их предсказания.
# Здесь используем `DecisionTreeRegressor` без ограничения `max_features` (т.е. все признаки доступны при каждом сплите).

# %%
import random
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
def manual_bagging_predict(
    X_train, y_train, X_test,
    n_estimators=50, max_samples=1.0,
    random_state=None
  ):
    # Инициализируем генератор случайных чисел для воспроизводимости
    rng = np.random.RandomState(random_state)

    # Размер обучающей выборки
    n_samples = X_train.shape[0]

    # Размер одной бутстрэп-выборки
    sample_size = int(max_samples * n_samples)

    preds_test = []   # список предсказаний от каждого дерева
    preds_train = []
    trees = []   # список обученных деревьев

    for i in range(n_estimators):
        # Сэмплируем индексы с возвращением (bootstrap)
        inds = rng.randint(0, n_samples, size=sample_size)
        Xt = X_train.iloc[inds]
        yt = y_train.iloc[inds]

        # Создаём и обучаем дерево решений
        tree = DecisionTreeRegressor(random_state=rng.randint(0, 1_000_000))
        tree.fit(Xt, yt)

        trees.append(tree)
        preds_test.append(tree.predict(X_test))
        preds_train.append(tree.predict(X_train))

    # preds имеет форму (число деревьев, число объектов теста)
    preds_train = np.vstack(preds_train)
    preds_test = np.vstack(preds_test)

    # Усредняем предсказания по всем деревьям
    return preds_train.mean(axis=0), preds_test.mean(axis=0), trees

# %%
# обучим и оценим
y_pred_manual_bag_train, y_pred_manual_bag_test, bag_trees = manual_bagging_predict(
    X_train, y_train, X_test,
    n_estimators=300, max_samples=1.0, random_state=0
)

print_metrics('Manual Bagging (50 trees)', y_train, y_pred_manual_bag_train)
print_metrics('Manual Bagging (50 trees)', y_test, y_pred_manual_bag_test)
# Out:
# Manual Bagging (50 trees): RMSE=20.7106, MAE=17.0309, R2=0.9258
# Manual Bagging (50 trees): RMSE=62.2419, MAE=50.8110, R2=0.3898

# %% [markdown]
# ## Ручной Random Forest
#
# Отличие от бэггинга: при построении каждого сплита дерево рассматривает только случайное подмножество признаков (`max_features`).
# Мы реализуем это, создавая деревья `DecisionTreeRegressor` с параметром `max_features='sqrt'` (как часто используют для регрессии — sqrt(n_features)).

# %%
# help(DecisionTreeRegressor)

# %%
def manual_random_forest_predict(
    X_train, y_train, X_test,
    n_estimators=50, max_samples=1.0,
    max_features='sqrt', random_state=None
):
    # Инициализация генератора случайных чисел
    rng = np.random.RandomState(random_state)

    # Количество объектов в обучающей выборке
    n_samples = X_train.shape[0]
    # Размер выборки для каждого дерева (bootstrap-сэмпл)
    sample_size = int(max_samples * n_samples)

    preds = []   # список предсказаний от каждого дерева
    trees = []   # список обученных деревьев

    # Строим n_estimators деревьев
    for i in range(n_estimators):
        # Случайный bootstrap-сэмпл из обучающей выборки
        inds = rng.randint(0, n_samples, size=sample_size)
        Xt = X_train.iloc[inds]
        yt = y_train.iloc[inds]

        # Дерево с ограничением по числу признаков (max_features)
        # Это и отличает случайный лес от простого бэггинга
        tree = DecisionTreeRegressor(
            max_features=max_features,
            random_state=rng.randint(0, 1_000_000),
            min_samples_leaf=15
        )

        # Обучение дерева
        tree.fit(Xt, yt)

        # Сохраняем дерево и его предсказания
        trees.append(tree)
        preds.append(tree.predict(X_test))

    # Собираем предсказания всех деревьев в матрицу
    # размерности (n_estimators, n_test)
    preds = np.vstack(preds)

    # Возвращаем среднее предсказание и список деревьев
    return preds.mean(axis=0), trees

# %%
# обучим и оценим
y_pred_manual_rf, rf_trees = manual_random_forest_predict(
    X_train, y_train, X_test,
    n_estimators=200, max_samples=1.0,
    max_features='sqrt', random_state=0
)
print_metrics('Manual Random Forest (50 trees, max_features=sqrt)', y_test, y_pred_manual_rf)
# Out:
# Manual Random Forest (50 trees, max_features=sqrt): RMSE=60.2881, MAE=50.5861, R2=0.4275

# %% [markdown]
# ## Сравнение с `sklearn` (BaggingRegressor и RandomForestRegressor)

# %%
# sklearn BaggingRegressor
br = BaggingRegressor(
    estimator=DecisionTreeRegressor(),
    n_estimators=50,
    max_samples=1.0,
    random_state=0
)
br.fit(X_train, y_train)
y_pred_sklearn_bag = br.predict(X_test)
print_metrics('sklearn BaggingRegressor (50 trees)', y_test, y_pred_sklearn_bag)

# sklearn RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=50, max_features='sqrt', random_state=42)
rfr.fit(X_train, y_train)
y_pred_sklearn_rf = rfr.predict(X_test)
print_metrics('sklearn RandomForestRegressor (50 trees, max_features=sqrt)', y_test, y_pred_sklearn_rf)
# Out:
# sklearn BaggingRegressor (50 trees): RMSE=62.7542, MAE=50.5000, R2=0.3797
# sklearn RandomForestRegressor (50 trees, max_features=sqrt): RMSE=62.8414, MAE=52.5321, R2=0.3780

# %%
!  pip -q install optuna

# %%
# Подбор гиперпараметров для RandomForestRegressor с помощью Optuna

import optuna

def objective(trial):
    # Определяем пространство поиска гиперпараметров
    n_estimators = trial.suggest_int('n_estimators', 50, 500)
    max_depth = trial.suggest_int('max_depth', 1, 32, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])

    # Создаем модель RandomForestRegressor с заданными гиперпараметрами
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42,
        n_jobs=-1 # Используем все доступные ядра процессора
    )

    # Обучаем модель
    model.fit(X_train, y_train)

    # Предсказываем на тестовой выборке
    y_pred = model.predict(X_test)

    # Вычисляем метрику (например, RMSE)
    rmse = sqrt(mean_squared_error(y_test, y_pred))

    return rmse

# Создаем исследование Optuna
study = optuna.create_study(direction='minimize')

# Запускаем оптимизацию. Можно указать количество испытаний (n_trials)
study.optimize(objective, n_trials=100)

# Выводим лучшие гиперпараметры и лучшую метрику
print("Best hyperparameters: ", study.best_params)
print("Best RMSE: ", study.best_value)

# Обучаем финальную модель с лучшими гиперпараметрами
best_rfr = RandomForestRegressor(**study.best_params, random_state=42, n_jobs=-1)
best_rfr.fit(X_train, y_train)
y_pred_best_rfr = best_rfr.predict(X_test)

# Оцениваем финальную модель на тестовой выборке
print_metrics('sklearn RandomForestRegressor (tuned)', y_test, y_pred_best_rfr)
# Out:
# [I 2026-01-10 22:03:49,782] A new study created in memory with name: no-name-e3516fa0-cbac-4611-8880-744c7b79520c
# [I 2026-01-10 22:03:50,427] Trial 0 finished with value: 66.64796819930255 and parameters: {'n_estimators': 386, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: 66.64796819930255.
# [I 2026-01-10 22:03:50,610] Trial 1 finished with value: 59.688216069646536 and parameters: {'n_estimators': 115, 'max_depth': 22, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:50,975] Trial 2 finished with value: 60.5746734515728 and parameters: {'n_estimators': 188, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:51,683] Trial 3 finished with value: 65.05221877282548 and parameters: {'n_estimators': 333, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:52,081] Trial 4 finished with value: 60.37283606975153 and parameters: {'n_estimators': 210, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 11, 'max_features': 'log2'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:52,254] Trial 5 finished with value: 67.35407306789209 and parameters: {'n_estimators': 105, 'max_depth': 1, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:52,636] Trial 6 finished with value: 65.01508888466107 and parameters: {'n_estimators': 252, 'max_depth': 1, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:52,850] Trial 7 finished with value: 61.03147486195058 and parameters: {'n_estimators': 70, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:53,479] Trial 8 finished with value: 60.64488231257949 and parameters: {'n_estimators': 390, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:53,636] Trial 9 finished with value: 62.819789396176425 and parameters: {'n_estimators': 84, 'max_depth': 2, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:54,438] Trial 10 finished with value: 60.190997611397414 and parameters: {'n_estimators': 497, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:55,182] Trial 11 finished with value: 60.29075503241917 and parameters: {'n_estimators': 476, 'max_depth': 29, 'min_samples_split': 8, 'min_samples_leaf': 19, 'max_features': 'log2'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:55,450] Trial 12 finished with value: 60.08003426668296 and parameters: {'n_estimators': 152, 'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 17, 'max_features': 'log2'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:55,722] Trial 13 finished with value: 60.69666254348294 and parameters: {'n_estimators': 151, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 15, 'max_features': 'log2'}. Best is trial 1 with value: 59.688216069646536.
# [I 2026-01-10 22:03:55,989] Trial 14 finished with value: 59.67006561894484 and parameters: {'n_estimators': 122, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 14 with value: 59.67006561894484.
# [I 2026-01-10 22:03:56,099] Trial 15 finished with value: 59.84912605860105 and parameters: {'n_estimators': 54, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 14 with value: 59.67006561894484.
# [I 2026-01-10 22:03:56,518] Trial 16 finished with value: 59.71816307702705 and parameters: {'n_estimators': 261, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 14 with value: 59.67006561894484.
# [I 2026-01-10 22:03:56,734] Trial 17 finished with value: 60.277989766906344 and parameters: {'n_estimators': 135, 'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 14 with value: 59.67006561894484.
# [I 2026-01-10 22:03:57,103] Trial 18 finished with value: 59.753412166396714 and parameters: {'n_estimators': 223, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 14 with value: 59.67006561894484.
# [I 2026-01-10 22:03:57,642] Trial 19 finished with value: 59.62386961045001 and parameters: {'n_estimators': 319, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 19 with value: 59.62386961045001.
# [I 2026-01-10 22:03:58,184] Trial 20 finished with value: 61.222123646599115 and parameters: {'n_estimators': 338, 'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 19 with value: 59.62386961045001.
# [I 2026-01-10 22:03:58,664] Trial 21 finished with value: 59.82384799064719 and parameters: {'n_estimators': 306, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 19 with value: 59.62386961045001.
# [I 2026-01-10 22:03:59,003] Trial 22 finished with value: 59.77477439520645 and parameters: {'n_estimators': 183, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 19 with value: 59.62386961045001.
# [I 2026-01-10 22:03:59,193] Trial 23 finished with value: 59.508528263014874 and parameters: {'n_estimators': 108, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:03:59,668] Trial 24 finished with value: 59.64172065687447 and parameters: {'n_estimators': 294, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:00,273] Trial 25 finished with value: 59.734410357201796 and parameters: {'n_estimators': 393, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:00,736] Trial 26 finished with value: 61.17647372539575 and parameters: {'n_estimators': 311, 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:01,397] Trial 27 finished with value: 59.83618507226231 and parameters: {'n_estimators': 435, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:01,847] Trial 28 finished with value: 60.903859057073674 and parameters: {'n_estimators': 286, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_features': 'sqrt'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:02,437] Trial 29 finished with value: 59.61613823111933 and parameters: {'n_estimators': 362, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:02,971] Trial 30 finished with value: 62.41796605834591 and parameters: {'n_estimators': 349, 'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 15, 'max_features': 'sqrt'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:03,586] Trial 31 finished with value: 59.660333319166256 and parameters: {'n_estimators': 369, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:04,232] Trial 32 finished with value: 59.68173479640151 and parameters: {'n_estimators': 411, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:04,718] Trial 33 finished with value: 60.039473341719024 and parameters: {'n_estimators': 283, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:05,420] Trial 34 finished with value: 60.082684570871194 and parameters: {'n_estimators': 434, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:05,835] Trial 35 finished with value: 59.82596791724716 and parameters: {'n_estimators': 240, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 18, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:06,313] Trial 36 finished with value: 59.63298690702819 and parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:06,886] Trial 37 finished with value: 60.519580573679164 and parameters: {'n_estimators': 364, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:07,199] Trial 38 finished with value: 59.955573449839896 and parameters: {'n_estimators': 182, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:07,731] Trial 39 finished with value: 59.6947759841443 and parameters: {'n_estimators': 322, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:08,151] Trial 40 finished with value: 60.72708707275157 and parameters: {'n_estimators': 266, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:08,689] Trial 41 finished with value: 59.603640553081014 and parameters: {'n_estimators': 352, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:09,263] Trial 42 finished with value: 59.71534951099946 and parameters: {'n_estimators': 358, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:09,820] Trial 43 finished with value: 59.668608481562686 and parameters: {'n_estimators': 333, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:10,449] Trial 44 finished with value: 59.67383101840936 and parameters: {'n_estimators': 415, 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:11,071] Trial 45 finished with value: 60.05304640034022 and parameters: {'n_estimators': 375, 'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:11,559] Trial 46 finished with value: 60.25329844258102 and parameters: {'n_estimators': 314, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': 'sqrt'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:11,969] Trial 47 finished with value: 60.503387082597285 and parameters: {'n_estimators': 237, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 14, 'max_features': 'log2'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:12,510] Trial 48 finished with value: 59.77061737576062 and parameters: {'n_estimators': 345, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 18, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:13,260] Trial 49 finished with value: 59.825805755404616 and parameters: {'n_estimators': 394, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:14,012] Trial 50 finished with value: 61.42369824025942 and parameters: {'n_estimators': 459, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:14,471] Trial 51 finished with value: 59.5918049225046 and parameters: {'n_estimators': 292, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:14,993] Trial 52 finished with value: 59.63047891869935 and parameters: {'n_estimators': 294, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:15,453] Trial 53 finished with value: 59.62635238065564 and parameters: {'n_estimators': 270, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:15,670] Trial 54 finished with value: 59.60331318621425 and parameters: {'n_estimators': 101, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:15,844] Trial 55 finished with value: 61.05491874869277 and parameters: {'n_estimators': 89, 'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 11, 'max_features': 'log2'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:15,965] Trial 56 finished with value: 64.96762364030606 and parameters: {'n_estimators': 63, 'max_depth': 1, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:16,278] Trial 57 finished with value: 59.61111478149073 and parameters: {'n_estimators': 199, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:16,477] Trial 58 finished with value: 59.727212201748294 and parameters: {'n_estimators': 113, 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:16,752] Trial 59 finished with value: 59.78101528575735 and parameters: {'n_estimators': 166, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:16,921] Trial 60 finished with value: 61.27950030991682 and parameters: {'n_estimators': 84, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:17,124] Trial 61 finished with value: 59.55560650447236 and parameters: {'n_estimators': 104, 'max_depth': 26, 'min_samples_split': 11, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:17,440] Trial 62 finished with value: 59.564621185561386 and parameters: {'n_estimators': 133, 'max_depth': 32, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:17,664] Trial 63 finished with value: 59.59420204382296 and parameters: {'n_estimators': 130, 'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:17,927] Trial 64 finished with value: 59.57045261423901 and parameters: {'n_estimators': 132, 'max_depth': 31, 'min_samples_split': 11, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:18,146] Trial 65 finished with value: 59.727957478665154 and parameters: {'n_estimators': 135, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 18, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:18,385] Trial 66 finished with value: 59.653062060690964 and parameters: {'n_estimators': 141, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:18,697] Trial 67 finished with value: 59.53702003174068 and parameters: {'n_estimators': 118, 'max_depth': 32, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:18,993] Trial 68 finished with value: 60.14887362662622 and parameters: {'n_estimators': 166, 'max_depth': 28, 'min_samples_split': 11, 'min_samples_leaf': 19, 'max_features': 'log2'}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:19,207] Trial 69 finished with value: 59.54643811336595 and parameters: {'n_estimators': 123, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 23 with value: 59.508528263014874.
# [I 2026-01-10 22:04:19,401] Trial 70 finished with value: 59.41564645499526 and parameters: {'n_estimators': 106, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 70 with value: 59.41564645499526.
# [I 2026-01-10 22:04:19,620] Trial 71 finished with value: 59.480968212345125 and parameters: {'n_estimators': 120, 'max_depth': 32, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 70 with value: 59.41564645499526.
# [I 2026-01-10 22:04:19,821] Trial 72 finished with value: 59.38855526676993 and parameters: {'n_estimators': 101, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:20,020] Trial 73 finished with value: 59.44665167872754 and parameters: {'n_estimators': 100, 'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:20,183] Trial 74 finished with value: 59.52627880684019 and parameters: {'n_estimators': 74, 'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:20,379] Trial 75 finished with value: 59.52627880684019 and parameters: {'n_estimators': 74, 'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:20,489] Trial 76 finished with value: 59.59469813146019 and parameters: {'n_estimators': 51, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:20,638] Trial 77 finished with value: 59.50136766940362 and parameters: {'n_estimators': 75, 'max_depth': 32, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:20,795] Trial 78 finished with value: 61.25970988704008 and parameters: {'n_estimators': 73, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': 'sqrt'}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:20,926] Trial 79 finished with value: 59.62878018171254 and parameters: {'n_estimators': 66, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:21,101] Trial 80 finished with value: 59.665628319869114 and parameters: {'n_estimators': 88, 'max_depth': 28, 'min_samples_split': 7, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:21,288] Trial 81 finished with value: 59.4672439348953 and parameters: {'n_estimators': 78, 'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:21,482] Trial 82 finished with value: 59.4672439348953 and parameters: {'n_estimators': 78, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:21,682] Trial 83 finished with value: 59.56109289562633 and parameters: {'n_estimators': 98, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:21,920] Trial 84 finished with value: 59.467470299872396 and parameters: {'n_estimators': 112, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:22,200] Trial 85 finished with value: 59.68386894278864 and parameters: {'n_estimators': 150, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:22,423] Trial 86 finished with value: 59.61173117786276 and parameters: {'n_estimators': 110, 'max_depth': 32, 'min_samples_split': 7, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:22,610] Trial 87 finished with value: 59.548077573606406 and parameters: {'n_estimators': 90, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:22,754] Trial 88 finished with value: 60.2445168672517 and parameters: {'n_estimators': 55, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:22,919] Trial 89 finished with value: 59.75359067370192 and parameters: {'n_estimators': 79, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 18, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:23,105] Trial 90 finished with value: 59.5515825498149 and parameters: {'n_estimators': 94, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:23,280] Trial 91 finished with value: 59.70268546622837 and parameters: {'n_estimators': 60, 'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:23,480] Trial 92 finished with value: 59.475161476847425 and parameters: {'n_estimators': 109, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:23,694] Trial 93 finished with value: 59.44174539527845 and parameters: {'n_estimators': 108, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:23,930] Trial 94 finished with value: 59.456021507666236 and parameters: {'n_estimators': 121, 'max_depth': 25, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:24,153] Trial 95 finished with value: 59.57425144956232 and parameters: {'n_estimators': 123, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:24,396] Trial 96 finished with value: 59.5969630293546 and parameters: {'n_estimators': 148, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:24,688] Trial 97 finished with value: 59.7551542677328 and parameters: {'n_estimators': 169, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:24,898] Trial 98 finished with value: 60.46695845923841 and parameters: {'n_estimators': 103, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 'sqrt'}. Best is trial 72 with value: 59.38855526676993.
# [I 2026-01-10 22:04:25,132] Trial 99 finished with value: 59.441492780300564 and parameters: {'n_estimators': 113, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 72 with value: 59.38855526676993.
# Best hyperparameters:  {'n_estimators': 101, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None}
# Best RMSE:  59.38855526676993
# sklearn RandomForestRegressor (tuned): RMSE=59.3886, MAE=48.6889, R2=0.4445

# %%
# Соберём все метрики в таблицу для наглядного сравнения
results = []
models = [
    ('DecisionTree', y_pred_tree_test),
    ('Manual Bagging', y_pred_manual_bag_test),
    ('Manual RandomForest', y_pred_manual_rf),
    ('sklearn Bagging', y_pred_sklearn_bag),
    ('sklearn RandomForest', y_pred_sklearn_rf),
]
for name, pred in models:
    m = regression_metrics(y_test, pred)
    results.append({'model': name, **m})
res_df = pd.DataFrame(results).set_index('model')
res_df
# Out:
#                            RMSE        MAE        R2
# model
# DecisionTree          66.714321  53.928441  0.298977
# Manual Bagging        62.241909  50.811021  0.389818
# Manual RandomForest   60.288058  50.586149  0.427525
# sklearn Bagging       62.754163  50.500000  0.379733
# sklearn RandomForest  62.841350  52.532072  0.378008

# %% [markdown]
# ## Важности признаков (feature importances)
#
# Для ансамблей усредним важности по отдельным деревьям: mean(feature_importances_).
# Сравним: manual bagging, manual rf, sklearn rf.

# %%
# Важности для manual bagging
importances_bag = np.mean([t.feature_importances_ for t in bag_trees], axis=0)
importances_mrf = np.mean([t.feature_importances_ for t in rf_trees], axis=0)
importances_sklearn_rf = rfr.feature_importances_

feat_names = X_train.columns.tolist()
fi_df = pd.DataFrame({
    'feature': feat_names,
    'manual_bagging': importances_bag,
    'manual_random_forest': importances_mrf,
    'sklearn_random_forest': importances_sklearn_rf
}).set_index('feature')
fi_df_sorted = fi_df.sort_values('sklearn_random_forest', ascending=True)
fi_df_sorted
# Out:
#          manual_bagging  manual_random_forest  sklearn_random_forest
# feature
# sex            0.010428              0.006722               0.012719
# s1             0.046714              0.031410               0.065281
# s2             0.051538              0.034471               0.066065
# age            0.069572              0.027520               0.068014
# s4             0.019443              0.067042               0.070909
# s3             0.056939              0.066720               0.072077
# s6             0.047724              0.059886               0.081096
# bp             0.137737              0.182763               0.144015
# s5             0.324749              0.262815               0.208464
# bmi            0.235156              0.260650               0.211361

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# Построим горизонтальные столбчатые графики важности признаков по моделям
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(8, 10))

axs[0].barh(fi_df_sorted.index, fi_df_sorted['manual_bagging'])
axs[0].set_title('Manual Bagging feature importances')

axs[1].barh(fi_df_sorted.index, fi_df_sorted['manual_random_forest'])
axs[1].set_title('Manual Random Forest feature importances')

axs[2].barh(fi_df_sorted.index, fi_df_sorted['sklearn_random_forest'])
axs[2].set_title('sklearn RandomForest feature importances')

plt.tight_layout()
plt.show()
