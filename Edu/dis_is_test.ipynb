# %%
def test_is(x=1000, y=1000):
    # if x == y:
        return x is y

# %%
x=5
y=5

print(x is y)
print(test_is())
print(test_is(x=5, y=x))
# Out:
# True
# True
# True

# %%
test_is.__code__.co_consts
# Out:
# (None,)

# %%
test_is.__code__.co_varnames
# Out:
# ('x', 'y')

# %%
import dis
dis.dis(test_is)
# Out:
#   1           0 RESUME                   0
#
#   3           2 LOAD_FAST                0 (x)
#               4 LOAD_FAST                1 (y)
#               6 IS_OP                    0
#               8 RETURN_VALUE

# %%
x=5
y=int('5')
x is y
# Out:
# True
