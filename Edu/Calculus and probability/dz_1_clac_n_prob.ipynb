# %% [markdown]
# # Домашнее задание
#
# Студента Лысогора А.А.

# %% [markdown]
# Математический анализ
# 69 баллов

# %% [markdown]
# # **Задача 1** (14 баллов)
#
# Найдите экстремумы функции:
#
# $
# f(x, y, z)=2 x^3+2 x y+2 x z+y^2+z^2+2 y-8 .
# $

# %% [markdown]
# ## Подробное решение:

# %% [markdown]
# ![частные производные первого порядкка](1_dz_1_1.jpg)

# %% [markdown]
# $f'x = 6x^2 + 2y + 2z$
#
# $f'y = 2x + 2y + 2$
#
# $f'z = 2x + 2$
#
# $P_1 = (1,−2,−1)$,
# $P_2 = (-\frac{1}{3},-\frac{2}{3},\frac{1}{3})$

# %% [markdown]
# ![частные производные второго порядка](1_dz_1_2.jpg)

# %% [markdown]
# $P_1 = (1,−2,−1)$ - локальный минимум
#
# $P_2 = (-\frac{1}{3},-\frac{2}{3},\frac{1}{3})$ - седловая точка

# %% [markdown]
# $
# f(x, y, z)=2 x^3+2 x y+2 x z+y^2+z^2+2 y-8
# $
#
# $
# f(1, -2, -1)=2 \cdot (1)^3+2 \cdot 1 \cdot (-2) + 2 \cdot 1 \cdot (-1) + (-2)^2+(-1)^2+2 \cdot (-2)-8
# = 2 - 4 - 2 + 4 + 1 - 4 - 8 = -11
# $

# %% [markdown]
# ## Ответ:
#
# $P_1 = (1,−2,−1)$ $-$ локальный минимум (локальный, так как функция может принимать и более минимальные значения при $x$ стремящимся к минус бесконечности.
#
# $f(1, -2, -1)= -11$, значение функции в этой точке

# %% [markdown]
# # Задача 2 (25 баллов)
#
# Найдите условные экстремумы функции:
#
# $
# f(x, y)=4 x+8 y, y^2-2 x y+5=0
# $
#
# Вычислите результат самостоятельно (вручную) и с помощью Python. Сравните результаты.

# %% [markdown]
# ## Самостоятельно вычисление (вручную):

# %% [markdown]
# ![условные экстремумы](1_dz_2.jpg)

# %%
# сохраним полученные занчения для сравнения
from sympy import *
a, b, w = symbols('a b w' )
solutions_manual = [{a: -3, b: -1, w: -2}]
solutions_manual.append({a: 3, b: 1, w: 2})

# %%
solutions_manual
# Out:
# [{a: -3, b: -1, w: -2}, {a: 3, b: 1, w: 2}]

# %% [markdown]
# ## Вычисление с помощью Python:

# %%
from sympy import *
a, b, w = symbols('a b w' )

g = 4*a + 8*b
print('Целевая функция для аргументов a и b :\n f = ', g)

q = b**2 - 2*a*b + 5
print('Функция ограничений: ', q,'= 0')

f = 4*a + 8*b + w * (b**2 - 2*a*b + 5)
print('Функция Лагранжа :\n ', f)

fa = f.diff(a)
print('df/da =', fa,'= 0')

fb = f.diff(b)
print('df/db =', fb,'= 0')

fw = f.diff(w)
print('df/dw =', fw,'= 0')

solutions = solve([fa, fb, fw], (a, b, w), dict=True)
print('Стационарная точка M(x,y)_1:\n',float(solutions[0][a]),',',float(solutions[0][b]))
print('Стационарная точка M(x,y)_2:\n',float(solutions[1][a]),',',float(solutions[1][b]))
# Out:
# Целевая функция для аргументов a и b :
#  f =  4*a + 8*b
# Функция ограничений:  -2*a*b + b**2 + 5 = 0
# Функция Лагранжа :
#   4*a + 8*b + w*(-2*a*b + b**2 + 5)
# df/da = -2*b*w + 4 = 0
# df/db = w*(-2*a + 2*b) + 8 = 0
# df/dw = -2*a*b + b**2 + 5 = 0
# Стационарная точка M(x,y)_1:
#  -3.0 , -1.0
# Стационарная точка M(x,y)_2:
#  3.0 , 1.0

# %% [markdown]
# ## Сравнение результатов:

# %%
#сравним значения рассчитанные с помощью Python (слева) и расчитанные вручную
print(solutions[0][a] == solutions_manual[0][a])
print(solutions[0][b] == solutions_manual[0][b])
print(solutions[0][w] == solutions_manual[0][w])
print(solutions[1][a] == solutions_manual[1][a])
print(solutions[1][b] == solutions_manual[1][b])
print(solutions[1][w] == solutions_manual[1][w])
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# **Ответ:** Условные экстремумы функции находятся:
# * в точке $(-3, -1)$ - условный минимум, со значением функции в этой точке равным $-20$
# * и в точке $(3, 1)$ - условный максимум, значение функции в этой точке $20$.
#
# Значения рассчитаные вручную и с помощью Python - одинаковые.

# %% [markdown]
# # **Задача 3** (30 баллов)
#
# Вам предложены данные с информацией о успеваемости студентов:
#
# Независимые переменные:
# * Hours Studied: Общее количество часов, потраченных на учебу каждым студентом.
# * Previous Scores: Баллы, полученные студентами на предыдущих экзаменах.
# * Sleep Hours: Среднее количество часов сна студента в сутки.
# * Sample Question Papers Practiced: Количество пробных экзаменационных работ, с которыми студент занимался.
#
# Целевая переменная:
# * Performance Index: Показатель общей успеваемости каждого студента. Индекс успеваемости отражает академическую успеваемость студента и округляется до ближайшего целого числа. Индекс варьируется от 10 до 100, при этом более высокие значения свидетельствуют о более высокой успеваемости.
#
# Решите задачу линейной регрессии, реализовав градиентный спуск самостоятельно, не используя готовое решение из какой-либо библиотеки.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Student_Performance.txt')

df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
X = df[['Hours Studied', 'Previous Scores', 'Sleep Hours', 'Sample Question Papers Practiced']].values

y = df['Performance Index']
n = len(y)
X = np.append(np.ones((n, 1)), X, axis=1)

y = df['Performance Index'].values.reshape(n, 1)

par = np.zeros((5, 1))

def performance_index(X, y, par):
    y_pred = np.dot(X, par)
    error = (y_pred - y)**2
    perfect = (1/(2*n)) * np.sum(error)

    return perfect


def grad_d(X, y, par, alpha, iterations):
    perf_ind = []
    for i in range(iterations):
        y_pred = np.dot(X, par)
        der = np.dot (X.transpose(), (y_pred - y))/ n
        par -= alpha * der
        perf_ind.append(performance_index(X, y, par))

        if i % 50_000 == 0:
            print(f"iter={i}", par[0], par[1], par[2], par[3], par[4])

    print(f"iter={i}", par[0], par[1], par[2], par[3], par[4])    
    return par, perf_ind

# 0.000384 - максимально возможный шаг, на бОльших значениях начинает вылетать
step = 0.000384

# меньше итераций, более приемлимое время, результат не точный, до первых трёх знаков
# iter = 700_000

# долго считает, но выдаёт результат равный библиотечному
iter = 2_300_000

par, perf_opt = grad_d(X, y, par, step, iter)
# Out:
# iter=0 [0.02120632] [0.11301969] [1.58977582] [0.13909183] [0.09811016]
# iter=50000 [-13.41107393] [2.4496453] [0.89597543] [-0.73966622] [-0.08886046]
# iter=100000 [-21.47783153] [2.60965933] [0.9441973] [-0.25773934] [0.02370262]
# iter=150000 [-26.34733307] [2.70627725] [0.97367992] [0.03320943] [0.09167474]
# iter=200000 [-29.28681273] [2.76460078] [0.99147742] [0.20884099] [0.13270619]
# iter=250000 [-31.06123269] [2.79980784] [1.0022209] [0.31486116] [0.15747487]
# iter=300000 [-32.13236314] [2.82106061] [1.00870622] [0.37886035] [0.17242651]
# iter=350000 [-32.77895215] [2.83388987] [1.01262108] [0.41749353] [0.18145209]
# iter=400000 [-33.16926628] [2.84163427] [1.0149843] [0.44081448] [0.18690038]
# iter=450000 [-33.40487981] [2.84630919] [1.01641085] [0.4548922] [0.19018925]
# iter=500000 [-33.54710816] [2.8491312] [1.01727199] [0.46339023] [0.19217458]
# iter=550000 [-33.63296445] [2.85083471] [1.01779182] [0.46852008] [0.19337303]
# ...

# %% [markdown]
# Расчитаем и выведем значения из библиотеки scikit-learn (sklearn):

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [[0.         2.85342921 1.01858354 0.47633298 0.1951983 ]]
# [-33.76372609]

# %% [markdown]
# **Ответ:** парметры совпадают.

# %%
par
# Out:
# array([[-33.76372609],
#        [  2.85342921],
#        [  1.01858354],
#        [  0.47633298],
#        [  0.1951983 ]])

# %%
import numpy as np
import statsmodels.api as sm
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                 2.147e+05
# Date:                Mon, 10 Nov 2025   Prob (F-statistic):               0.00
# Time:                        13:45:51   Log-Likelihood:                -21418.
# No. Observations:               10000   AIC:                         4.285e+04
# Df Residuals:                    9995   BIC:                         4.288e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -33.7637      0.127   -266.189      0.000     -34.012     -33.515
# ...
