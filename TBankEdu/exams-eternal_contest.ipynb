# %% [markdown]
# Костя подключен к мобильному оператору «Мобайл». Абонентская плата Кости составляет <b><i>A</i></b> рублей в месяц. За эту стоимость Костя получает <b><i>B</i></b> мегабайт интернет-трафика. Если Костя выйдет за лимит трафика, то каждый следующий мегабайт будет стоить ему <b><i>C</i></b> рублей.
# Костя планирует потратить <b><i>D</i></b> мегабайт интернет-трафика в следующий месяц. Помогите ему сосчитать, во сколько рублей ему обойдется интернет.
#
# <b>Формат входных данных</b>
# Вводится 4 целых положительных числа   — стоимость тарифа Кости, размер тарифа Кости, стоимость каждого лишнего мегабайта, размер интернет-трафика Кости в следующем месяце. Числа во входном файле разделены пробелами.
#
#
# <b>Формат выходных данных</b>
# Выведите одно натуральное число — суммарные расходы Кости на интернет.

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())

x = a

if d > b:
    x += (d - b) * c

print(x)
# Out:
#  100
#  10
#  12
#  1
# 100

# %% [markdown]
# Ваня принес на кухню рулет, который он хочет разделить с коллегами. Для этого он хочет разрезать рулет на <b><i>N</i></b> равных частей. Разумеется, рулет можно резать только поперек. Соотвественно, Костя сделает <b><i>N - 1</i></b> разрез ножом через равные промежутки.
#
# По возвращению с кофе-брейка Ваня задумался — а можно ли было обойтись меньшим числом движений, будь нож Вани бесконечно длинным (иначе говоря, если он мог бы сделать сколько угодно разрезов за раз, если эти разрезы лежат на одной прямой)? Считается, что места для разрезов намечены заранее, и все разрезы делаются с ювелирной точностью.
# Оказывается, что можно. Например, если Ваня хотел бы разделить рулет на <b><i>4</i></b> части, он мог бы обойтись двумя разрезами — сначала он разделил бы рулет на две половинки, а потом совместил бы две половинки и разрезал обе пополам одновременно.
#
# Вам дано число <b><i>N</i></b>, требуется сказать, каким минимальным числом разрезов можно обойтись.

# %%
import math

piece = int(input())
cut = math.log(piece, 2)
cut = math.ceil(cut)
print(cut)
# Out:
#  5
# 3

# %% [markdown]
# Минимальное количество пролётов.
#
# Формат входных данных
# В первой строке вводятся целые положительные числа  и   — количество сотрудников и время, когда один из сотрудников покинет офис (в минутах). В следующей строке n чисел — номера этажей, на которых находятся сотрудники. Все числа различны и по абсолютной величине не превосходят 100. Номера этажей даны в порядке возрастания. В следующей строке записан номер сотрудника, который уйдет через t минут.
#
# Формат выходных данных
# Выведите одно число — минимально возможное число лестничных пролетов, которое понадобится пройти Кате.
#
# 5  5
#
# 1  4  9  16  25
#
# 2

# %%
n, t = [int(x) for x in input().split()]
stairs = list(map(int, input().split()))
nt = int(input())
optimum = stairs[-1] - stairs[0]
down = stairs[nt-1] - stairs[0]
up = stairs[-1] - stairs[nt-1]
lag = min(down, up)
if lag < t: lag = 0
min_stairs = optimum + lag
print(min_stairs)
# Out:
#  6 4
#  1 2 3 6 8 25
#  5
# 31

# %% [markdown]
# Пример 2
#
# 6  4
#
# 1  2  3  6  8  25
#
# 5

# %% [markdown]
# Леше в институте рассказали Малую теорему Ферма:
# , где  — простое
# С помощью этого утверждения можно искать обратное по модулю. А именно, если
#   то
# Теперь Леша решает домашнюю работу, в которой есть задача: надо посчитать .
# Помогите ему с этим.
#
# Формат входных данных
# Вводится три числа
#
# Формат выходных данных
# Выведите одно число — искомую сумму.

# %% [markdown]
# римеры данных
# Пример 1
# 1  5  7
# 1  5  7
# 1
# 1
# Пример 2
# 3  10  31
# 3  10  31
# 4

# %% [markdown]
# Примеры данных
# Пример 1
# 1  5  7
#
# 1
#
# Пример 2
# 3  10  31
#
# 4

# %%
# maximum values
p = 730_737_037
l = 1
r = 10^7

# %%
# пользовательский ввод, код для вставки
l, r, p = [int(x) for x in input().split()]

sum = 0

for i in range(l, p):
    if i > r: 
        break

    sum += pow(i, p-2, p)

print(sum % p)
# Out:
#  3 10 31
# 4

# %%
sum = 0

for i in range(l, p):
    if i > r: 
        break

    sum += pow(i, p-2, p)

sum % p
# Out:
# 39118241

# %% [markdown]
# Задание 12

# %% [markdown]
# У Артемия есть бесконечное число монет, каждая из которых одного из трех номиналов. Его интересует, какие суммы от 1 до N рублей он может набрать в свой кошелек, если там заранее лежала монета величиной в 1 рубль.
#
# Формат входных данных
# Первая строка содержит число N — ограничение на сумарную стоимость монет в кошельке (1 <= N <= 10^18).
# Вторая строка содержит три числа A, B, C задающие достоинства типов монет (1 <= A, B, C <= 100000).
#
# Формат выходных данных
# Выведите единственное число — количество сумм, которые можно набрать в кошельке.

# %% [markdown]
# Ответ. Используем перебор сочетаний A B C, по одному, по двум и по трём в порядке возрастания.

# %%
import itertools

a, b, c = 4, 7, 9
max_val = 15
my_list = [a, b, c]
comb_all = []
val_count = {1,}

for i in range(3):
    for combination in itertools.combinations_with_replacement(my_list, i+1):
        comb_all.append(combination)

# %%
val = 0
for comb in comb_all:
    val = 1 + sum(comb)
    if max_val >= val:
        val_count.add(val)

# %%
val_count, len(val_count)
# Out:
# ({1, 5, 8, 9, 10, 12, 13, 14, 15}, 9)

# %%
#for paste
import itertools

max_val = int(input())
my_list = list(map(int, input().split()))
my_list.sort()

comb_all = []
val_count = {1,}

for i in range(3):
    for combination in itertools.combinations_with_replacement(my_list, i+1):
        comb_all.append(combination)

val = 0
for comb in comb_all:
    val = 1 + sum(comb)
    if max_val >= val:
        val_count.add(val)

print(len(val_count))
# Out:
#  15
#  4 7 9
# 9

# %% [markdown]
# Задание 9

# %% [markdown]
# Даня в обеденный перерыв ходит в одно и то же кафе. Ему, как сотруднику банка, положено специальное предложение: при каждой покупке больше, чем на 100 рублей, Даня получает купон на бесплатный обед.
# Даня узнал стоимость своих обедов на ближайшие n дней. Ему хочется минимизировать свои затраты, грамотно используя талоны. Требуется найти минимальные суммарные затраты Дани на обеды.
#
# Формат входных данных
# В первой строке дается натуральное число n дней. Далее в каждой из строк записана стоимость обеда в каждой из дней (неотрицательное целое число, не больше, чем 3).
#
# Формат выходных данных
# В первой строке выдайте минимально возможную суммарную стоимость обедов.

# %%
#for the paste
lunch_cost = []
days = int(input())
for i in range(days):
    lunch_cost.append(int(input()))

for day, lunch in enumerate(lunch_cost):
    if lunch > 100:
        lunch_cost.remove(max(lunch_cost[day+1:]))

print(sum(lunch_cost))
# Out:
#  5
#  35
#  40
#  101
#  59
#  63
# 235

# %%
days = 5
lunch_cost = [35, 40, 101, 59, 63]
lunch_cost = [35, 40, 101, 59, 63, 101, 200, 101, 300, 99, 99]


for day, lunch in enumerate(lunch_cost):
    if lunch > 100:
        print(day, lunch_cost.index(max(lunch_cost[day+1:])))
        lunch_cost.remove(max(lunch_cost[day+1:]))

print(sum(lunch_cost))
# Out:
# 2 8
# 5 6
# 6 7
# 599

# %% [markdown]
# Задание 4
#
# У Кости есть бумажка, на которой написано n чисел. Также у него есть возможность не больше, чем k раз, взять любое число с бумажки, после чего закрасить одну из старых цифр, а на ее месте написать новую произвольную цифру.
# На какое максимальное значение Костя сможет увеличить сумму всех чисел на листочке?
#
# Формат входных данных
# В первой строке входного файла даны два целых числа n, k — количество чисел на бумажке и ограничение на число операций.
# (1 <= n <= 1000, 1 <= k <= 10^4).
#
# Во второй строке записано n чисел a(i) — числа на бумажке (1 <= a(i) <= 10^9)
#
# Формат выходных данных
# В выходной файл выведите одно число — максимальную разность между конечной и начальной суммой.

# %%
import heapq

n, k = map(int, input().split())
numbers = list(map(int, input().split()))

heap = []

for num in numbers:
    s = str(num)
    for i, ch in enumerate(s):
        current_digit = int(ch)
        gain = (9 - current_digit) * (10 ** (len(s) - i - 1))
        heapq.heappush(heap, -gain)  # Используем min-heap как max-heap

max_increase = 0
operations_used = 0

while heap and operations_used < k:
    current_gain = -heapq.heappop(heap)
    max_increase += current_gain
    operations_used += 1

print(max_increase)
# Out:
#  1 10
#  9999
# 0

# %% [markdown]
# Задание 5
#
# Во время разработки некоторой задачи Саша решил сгенерировать несколько новых тестов. Каждый тест Саши должен представлять собой натуральное число, не меньшее l и не большее r. Кроме того, натуральное число в тесте обязательно должно состоять из одинаковых цифр.
# Например, число 999 подходит под это требование, а число 123 — нет. Какое максимальное число различных тестов сможет создать Саша?
#
# Формат входных данных
# В единственной строке вводятся два натуральных числа l, r (1 <= l, r <= 10^18) — ограничения на тесты Саши.
# Обратите внимания, что эти числа не вместятся в 32-битный тип данных, используйте 64-битный при необходимости
#
# Формат выходных данных
# Выведите одно число — количество тестов, которое может сделать Саша.

# %%
l, r = map(int, input().split())

count = 0

for d in range(1, 10):  # Цифры от 1 до 9
    num = 0
    for length in range(1, 19):  # Числа длиной от 1 до 18 цифр
        num = num * 10 + d  # Генерируем число из length одинаковых цифр d
        if l <= num <= r:
            count += 1
        if num > r:
            break  # Дальнейшие числа будут только больше

print(count)
# Out:
#  10 100
# 9

# %% [markdown]
# Задание 8
#
# Миша сидел в переговорке и решил нарисовать ее план на листке бумаги. Когда он закончил рисовать план переговорки, он положил лист с планом на пол переговорки. Теперь ему стало интересно: а есть ли на плане точка, которая лежит ровно на том месте пола, за которое она отвечает?
# Помогите ему найти эту точку.
#
# Формат входных данных
# Переговорка и ее план имеют форму прямоугольника. Первая строка содержит два вещественных числа: координаты X и Y переговорки (1 <= X <= 1000, 1 <= Y <= 1000). Координаты углов переговорки равны (0, 0), (X, 0), (X, Y), (0, Y).
#
# Во второй строке даются восемь вещественных чисел, описывающих положение углов плана переговорки. Сначала вводятся координаты того угла плана, который соответствует углу переговорки с координатами (0, 0), затем — (X, 0), (X, Y) наконец, (0, Y). Гарантируется, что входные данные корректны, то есть план является прямоугольником, линейные размеры которого соответствуют размерам переговорки, а также он не выходит за границы перегородки.
# Все числа вещественные, заданы с точностью 5 знаков после десятичной точки. План выполнен в масштабе не менее 0,0001 и строго менее 1.
#
# Формат выходных данных
# Выведите два вещественных числа — координаты неподвижной точки в координатах переговорки. Выводить число нужно с точностью не менее четырех знаков после запятой.
#
# Замечание
# Заметьте, что для читаемости условий входные данные в примере даются с меньшим количеством десятичных знаков. В реальных тестовых данных в координатах будут дополнительные нули на конце.

# %%
data = input().split()

# Чтение входных данных
X, Y = map(float, data[:2])
corners = list(map(float, data[2:10]))

# Углы плана: A, B, C, D (соответствуют (0,0), (X,0), (X,Y), (0,Y))
A = (corners[0], corners[1])  # (0,0)
B = (corners[2], corners[3])  # (X,0)
C = (corners[4], corners[5])  # (X,Y)
D = (corners[6], corners[7])  # (0,Y)

# Находим коэффициенты аффинного преобразования
# x' = a*x + b*y + c
# y' = d*x + e*y + f
# Известны преобразования углов:
# (0,0) -> A
# (X,0) -> B
# (X,Y) -> C

# Система уравнений для a, b, c:
# A: 0*a + 0*b + c = A_x => c = A_x
# B: X*a + 0*b + c = B_x => a = (B_x - c)/X
# C: X*a + Y*b + c = C_x => b = (C_x - X*a - c)/Y

c = A[0]
a = (B[0] - c) / X
b = (C[0] - a * X - c) / Y

# Аналогично для d, e, f:
f = A[1]
d = (B[1] - f) / X
e = (C[1] - d * X - f) / Y

# Теперь решаем систему:
# x = a*x + b*y + c
# y = d*x + e*y + f
# Перепишем:
# (1 - a)*x - b*y = c
# -d*x + (1 - e)*y = f

# Матрица системы:
# | (1 - a)   -b     |   |x|   |c|
# |   -d     (1 - e)  | * |y| = |f|

# Определитель матрицы
det = (1 - a) * (1 - e) - (-b) * (-d)

if abs(det) < 1e-9:
    # Бесконечно много решений или нет решений
    # По условию гарантируется, что решение есть
    # Найдем любое решение (например, если план не повернут)
    # Тогда неподвижная точка — центр
    x = X / 2
    y = Y / 2
else:
    # Решение по методу Крамера
    det_x = c * (1 - e) - (-b) * f
    det_y = (1 - a) * f - (-d) * c
    x = det_x / det
    y = det_y / det

# Проверяем, что точка внутри переговорки
x = max(0.0, min(X, x))
y = max(0.0, min(Y, y))

print("{0:.5f} {1:.5f}".format(x, y))
# Out:
#  10 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 8
#       5 corners = list(map(float, data[2:10]))
#       7 # Углы плана: A, B, C, D (соответствуют (0,0), (X,0), (X,Y), (0,Y))
# ----> 8 A = (corners[0], corners[1])  # (0,0)
#       9 B = (corners[2], corners[3])  # (X,0)
#      10 C = (corners[4], corners[5])  # (X,Y)
#
# IndexError: list index out of range

# %%
X, Y = map(float, input().split())
coords = list(map(float, input().split()))
x1, y1 = coords[0], coords[1]
x2, y2 = coords[2], coords[3]
x3, y3 = coords[4], coords[5]
x4, y4 = coords[6], coords[7]

# Находим коэффициенты аффинного преобразования
# x' = a * x + b * y + c
# y' = d * x + e * y + f
# Из (0,0) → (x1,y1): c = x1, f = y1
c = x1
f = y1

# Из (X,0) → (x2,y2): a*X + c = x2 => a = (x2 - c)/X
a = (x2 - c) / X
d = (y2 - f) / X

# Из (0,Y) → (x4,y4): b*Y + c = x4 => b = (x4 - c)/Y
b = (x4 - c) / Y
e = (y4 - f) / Y

# Неподвижная точка: x = a*x + b*y + c, y = d*x + e*y + f
# => (1 - a)*x - b*y = c
#    -d*x + (1 - e)*y = f
A = (1 - a)
B = -b
C = c
D = -d
E = (1 - e)
F = f

# Решаем систему методом Крамера
det = A * E - B * D
if abs(det) < 1e-9:
    # В случае вырожденной системы (например, план совпадает с реальностью)
    print(0.0, 0.0)

det_x = C * E - B * F
det_y = A * F - C * D

x = det_x / det
y = det_y / det

print(f"{x:.5f} {y:.5f}")
# Out:
#  10 5
#  3.0  2.5  1.0  2.5  1.0  1.5  3.0  1.5
# 2.50000 2.08333
