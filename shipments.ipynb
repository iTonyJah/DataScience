# %% [markdown]
# # skip for a while

# %%
sh_stat_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\Шипменты_группы_осн (XLSX).xlsx')

# %%
sh_stat = sh_stat_xlsx.copy()

# %%
sh_main_12m_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\sh_main_12m (XLSX).xlsx')

# %%
sh12 = sh_main_12m_xlsx.copy()

# %% [markdown]
# # load main data

# %%
import pandas as pd

# %%
sh_main_3m_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\sh_main_3m (XLSX).xlsx')

# %%
sh3 = sh_main_3m_xlsx.copy()

sh = sh3

# %%
if sh.iloc[-1,0] == 'Итого':
    shTot = sh.iloc[-1,].loc['Сумма без НДС']
    print('drop Итого', shTot)
    sh.drop(sh.tail(1).index, inplace=True)
# Out:
# drop Итого 773638275.44

# %%
round(sh['Сумма без НДС'].sum(), 2) == shTot
# Out:
# True

# %%
sh[['ИНН', 'Заказчик']] = sh['ИНН, Заказчик'].str.split(', ', expand=True, n=1)
sh[['Статья движения денежных средств', 'Договор']] = sh['Статья движения денежных средств, Договор'].str.split(', ', expand=True, n=1)

# %%
sh['Дата доставки'] = pd.to_datetime(sh['Дата доставки'], dayfirst=True, errors='coerce')
sh['Дата сбора'] = pd.to_datetime(sh['Дата сбора'], dayfirst=True, errors='coerce')
sh['period'] = sh['Дата доставки'].dt.strftime('%Y-%m')

# %%
# пример исправления даты 'на лету'
# sh.loc[3354, 'Дата сбора'] = '23.08.2023'
# sh.loc[85076, 'Дата сбора'] = '29.04.2024'

# %%
sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28896 entries, 0 to 28895
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Заявки на перевозку                        28896 non-null  object
#  1   ИНН, Заказчик                              28896 non-null  object
#  2   Статья движения денежных средств, Договор  28896 non-null  object
#  3   Грузоотправитель                           28896 non-null  object
#  4   Грузополучатель                            28896 non-null  object
#  5   Дата доставки                              28896 non-null  datetime64[ns]
#  6   Дата сбора                                 28896 non-null  datetime64[ns]
#  7   Адрес отправления                          28896 non-null  object
#  8   Адрес доставки                             28896 non-null  object
#  9   Город отправления                          28896 non-null  object
#  10  Город доставки                             28896 non-null  object
#  11  Вид перевозки                              28896 non-null  object
#  12  Номер авианакладной (HAWB)                 28896 non-null  float64
#  13  Вид транспорта                             28896 non-null  object
#  14  Организация                                28896 non-null  object
#  15  Информация о доставке                      9226 non-null   object
#  16  Комментарий для сбора и доставки           16682 non-null  object
#  17  Автор                                      28896 non-null  object
#  18  Дата создания                              28896 non-null  object
#  19  Контактное лицо отправителя                20156 non-null  object
#  20  Контактное лицо получателя                 23891 non-null  object
#  21  Грузоотправитель партнер                   28896 non-null  object
#  22  Грузополучатель партнер                    28896 non-null  object
#  23  Дата изменения                             28896 non-null  object
#  24  Изменил                                    28896 non-null  object
#  25  Ставка НДС                                 28892 non-null  object
#  26  Сумма включает НДС                         28896 non-null  object
#  27  Дата удаления                              30 non-null     object
#  28  Номер заявки клиента                       20655 non-null  object
#  29  Дата курса                                 28896 non-null  object
#  30  Количество мест                            28851 non-null  float64
#  31  Объем, м3                                  0 non-null      float64
#  32  Объемный вес, кг                           0 non-null      float64
#  33  Оценочная стоимость, руб                   28896 non-null  float64
#  34  Масса нетто, кг                            190 non-null    float64
#  35  Масса брутто, кг                           28896 non-null  float64
#  36  Сумма без НДС                              28753 non-null  float64
#  37  Сумма с НДС                                28753 non-null  float64
#  38  Оценочная стоимость, USD                   2082 non-null   float64
#  39  Оценочная стоимость, EUR                   869 non-null    float64
#  40  Оценочная стоимость, GBP                   21 non-null     float64
#  41  Оценочная стоимость, CNY                   863 non-null    float64
#  42  Оценочная стоимость, CHF                   9 non-null      float64
#  43  Оценочная стоимость, RUB                   26307 non-null  float64
#  44  Итоговая стоимость USD                     28896 non-null  float64
#  45  Группа заявок                              11404 non-null  float64
#  46  ИНН                                        28896 non-null  object
#  47  Заказчик                                   28896 non-null  object
#  48  Статья движения денежных средств           28896 non-null  object
#  49  Договор                                    28896 non-null  object
#  50  period                                     28896 non-null  object
# dtypes: datetime64[ns](2), float64(17), object(32)
# memory usage: 11.2+ MB

# %%
sh[sh['Сумма без НДС'].isna() == True].count().tail()
# Out:
# ИНН                                 143
# Заказчик                            143
# Статья движения денежных средств    143
# Договор                             143
# period                              143
# dtype: int64

# %%
sh.pivot_table(
    index = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins = True,
).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b7d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b7d9_level0_col0" class="col_heading level0 col0" >Сумма без НДС</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b7d9_level0_row0" class="row_heading level0 row0" >2025-06</th>
#       <td id="T_4b7d9_row0_col0" class="data row0 col0" >100,361,210</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row1" class="row_heading level0 row1" >2025-07</th>
#       <td id="T_4b7d9_row1_col0" class="data row1 col0" >114,716,506</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row2" class="row_heading level0 row2" >2025-08</th>
#       <td id="T_4b7d9_row2_col0" class="data row2 col0" >109,443,171</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row3" class="row_heading level0 row3" >2025-09</th>
#       <td id="T_4b7d9_row3_col0" class="data row3 col0" >124,588,751</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row4" class="row_heading level0 row4" >2025-10</th>
#       <td id="T_4b7d9_row4_col0" class="data row4 col0" >154,441,667</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row5" class="row_heading level0 row5" >2025-11</th>
#       <td id="T_4b7d9_row5_col0" class="data row5 col0" >105,975,096</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row6" class="row_heading level0 row6" >2025-12</th>
#       <td id="T_4b7d9_row6_col0" class="data row6 col0" >64,098,492</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row7" class="row_heading level0 row7" >2026-01</th>
#       <td id="T_4b7d9_row7_col0" class="data row7 col0" >13,382</td>
#     </tr>
#     <tr>
#       <th id="T_4b7d9_level0_row8" class="row_heading level0 row8" >All</th>
#       <td id="T_4b7d9_row8_col0" class="data row8 col0" >773,638,275</td>
#     </tr>
#   </tbody>
# </table>

# %%
city = 'Астрахань'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
city = 'Волгоград'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
city = 'Воронеж'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
city = 'Калуга'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
sh_reg = sh[region]

# %%
sh_reg.pivot_table(
    index = ['Заказчик', 'Вид перевозки'],
    columns = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins = True,
).style.format("{: .0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_492a8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >period</th>
#       <th id="T_492a8_level0_col0" class="col_heading level0 col0" >2025-06</th>
#       <th id="T_492a8_level0_col1" class="col_heading level0 col1" >2025-07</th>
#       <th id="T_492a8_level0_col2" class="col_heading level0 col2" >2025-08</th>
#       <th id="T_492a8_level0_col3" class="col_heading level0 col3" >2025-09</th>
#       <th id="T_492a8_level0_col4" class="col_heading level0 col4" >2025-10</th>
#       <th id="T_492a8_level0_col5" class="col_heading level0 col5" >2025-11</th>
#       <th id="T_492a8_level0_col6" class="col_heading level0 col6" >2025-12</th>
#       <th id="T_492a8_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Заказчик</th>
#       <th class="index_name level1" >Вид перевозки</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_492a8_level0_row0" class="row_heading level0 row0" rowspan="2">ВТБ Калуга</th>
#       <th id="T_492a8_level1_row0" class="row_heading level1 row0" >Банкоматы</th>
#       <td id="T_492a8_row0_col0" class="data row0 col0" > 800065</td>
#       <td id="T_492a8_row0_col1" class="data row0 col1" > 877542</td>
#       <td id="T_492a8_row0_col2" class="data row0 col2" > 1063532</td>
#       <td id="T_492a8_row0_col3" class="data row0 col3" > 944544</td>
#       <td id="T_492a8_row0_col4" class="data row0 col4" > 1015262</td>
#       <td id="T_492a8_row0_col5" class="data row0 col5" > 1015262</td>
#       <td id="T_492a8_row0_col6" class="data row0 col6" > nan</td>
#       <td id="T_492a8_row0_col7" class="data row0 col7" > 5716208</td>
#     </tr>
#     <tr>
#       <th id="T_492a8_level1_row1" class="row_heading level1 row1" >Дверь-в-Дверь</th>
#       <td id="T_492a8_row1_col0" class="data row1 col0" > nan</td>
#       <td id="T_492a8_row1_col1" class="data row1 col1" > nan</td>
#       <td id="T_492a8_row1_col2" class="data row1 col2" > nan</td>
#       <td id="T_492a8_row1_col3" class="data row1 col3" > nan</td>
#       <td id="T_492a8_row1_col4" class="data row1 col4" > 206627</td>
#       <td id="T_492a8_row1_col5" class="data row1 col5" > 204562</td>
#       <td id="T_492a8_row1_col6" class="data row1 col6" > 204562</td>
#       <td id="T_492a8_row1_col7" class="data row1 col7" > 615751</td>
#     </tr>
#     <tr>
#       <th id="T_492a8_level0_row2" class="row_heading level0 row2" >Россельхозбанк</th>
#       <th id="T_492a8_level1_row2" class="row_heading level1 row2" >Банкоматы</th>
#       <td id="T_492a8_row2_col0" class="data row2 col0" > 278250</td>
#       <td id="T_492a8_row2_col1" class="data row2 col1" > 243000</td>
#       <td id="T_492a8_row2_col2" class="data row2 col2" > 279833</td>
#       <td id="T_492a8_row2_col3" class="data row2 col3" > 253500</td>
#       <td id="T_492a8_row2_col4" class="data row2 col4" > 235667</td>
#       <td id="T_492a8_row2_col5" class="data row2 col5" > 250917</td>
#       <td id="T_492a8_row2_col6" class="data row2 col6" > 230000</td>
#       <td id="T_492a8_row2_col7" class="data row2 col7" > 1771167</td>
#     </tr>
#     <tr>
#       <th id="T_492a8_level0_row3" class="row_heading level0 row3" >All</th>
#       <th id="T_492a8_level1_row3" class="row_heading level1 row3" ></th>
#       <td id="T_492a8_row3_col0" class="data row3 col0" > 1078315</td>
#       <td id="T_492a8_row3_col1" class="data row3 col1" > 1120542</td>
#       <td id="T_492a8_row3_col2" class="data row3 col2" > 1343366</td>
#       <td id="T_492a8_row3_col3" class="data row3 col3" > 1198044</td>
#       <td id="T_492a8_row3_col4" class="data row3 col4" > 1457556</td>
#       <td id="T_492a8_row3_col5" class="data row3 col5" > 1470741</td>
#       <td id="T_492a8_row3_col6" class="data row3 col6" > 434562</td>
#       <td id="T_492a8_row3_col7" class="data row3 col7" > 8103126</td>
#     </tr>
#   </tbody>
# </table>

# %%
sh_reg.pivot_table(
    index = ['Заказчик'],
    columns = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins=True,
).style.format("{:.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc110">
#   <thead>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th id="T_bc110_level0_col0" class="col_heading level0 col0" >2025-06</th>
#       <th id="T_bc110_level0_col1" class="col_heading level0 col1" >2025-07</th>
#       <th id="T_bc110_level0_col2" class="col_heading level0 col2" >2025-08</th>
#       <th id="T_bc110_level0_col3" class="col_heading level0 col3" >2025-09</th>
#       <th id="T_bc110_level0_col4" class="col_heading level0 col4" >2025-10</th>
#       <th id="T_bc110_level0_col5" class="col_heading level0 col5" >2025-11</th>
#       <th id="T_bc110_level0_col6" class="col_heading level0 col6" >2025-12</th>
#       <th id="T_bc110_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Заказчик</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc110_level0_row0" class="row_heading level0 row0" >ВТБ Калуга</th>
#       <td id="T_bc110_row0_col0" class="data row0 col0" >800065</td>
#       <td id="T_bc110_row0_col1" class="data row0 col1" >877542</td>
#       <td id="T_bc110_row0_col2" class="data row0 col2" >1063532</td>
#       <td id="T_bc110_row0_col3" class="data row0 col3" >944544</td>
#       <td id="T_bc110_row0_col4" class="data row0 col4" >1221890</td>
#       <td id="T_bc110_row0_col5" class="data row0 col5" >1219824</td>
#       <td id="T_bc110_row0_col6" class="data row0 col6" >204562</td>
#       <td id="T_bc110_row0_col7" class="data row0 col7" >6331959</td>
#     </tr>
#     <tr>
#       <th id="T_bc110_level0_row1" class="row_heading level0 row1" >Россельхозбанк</th>
#       <td id="T_bc110_row1_col0" class="data row1 col0" >278250</td>
#       <td id="T_bc110_row1_col1" class="data row1 col1" >243000</td>
#       <td id="T_bc110_row1_col2" class="data row1 col2" >279833</td>
#       <td id="T_bc110_row1_col3" class="data row1 col3" >253500</td>
#       <td id="T_bc110_row1_col4" class="data row1 col4" >235667</td>
#       <td id="T_bc110_row1_col5" class="data row1 col5" >250917</td>
#       <td id="T_bc110_row1_col6" class="data row1 col6" >230000</td>
#       <td id="T_bc110_row1_col7" class="data row1 col7" >1771167</td>
#     </tr>
#     <tr>
#       <th id="T_bc110_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_bc110_row2_col0" class="data row2 col0" >1078315</td>
#       <td id="T_bc110_row2_col1" class="data row2 col1" >1120542</td>
#       <td id="T_bc110_row2_col2" class="data row2 col2" >1343366</td>
#       <td id="T_bc110_row2_col3" class="data row2 col3" >1198044</td>
#       <td id="T_bc110_row2_col4" class="data row2 col4" >1457556</td>
#       <td id="T_bc110_row2_col5" class="data row2 col5" >1470741</td>
#       <td id="T_bc110_row2_col6" class="data row2 col6" >434562</td>
#       <td id="T_bc110_row2_col7" class="data row2 col7" >8103126</td>
#     </tr>
#   </tbody>
# </table>

# %%
period = '2025-11'

# %%
sh_reg.period.describe()
# Out:
# count          16
# unique          7
# top       2025-10
# freq            3
# Name: period, dtype: object

# %%
sh_reg[sh_reg['period']==period].pivot_table(
    index = ['Заказчик', 'Вид перевозки', 'Заявки на перевозку',],
    columns = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins = True,
).drop('All', axis=1).style.format("{: .0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ba3e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >period</th>
#       <th id="T_1ba3e_level0_col0" class="col_heading level0 col0" >2025-11</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Заказчик</th>
#       <th class="index_name level1" >Вид перевозки</th>
#       <th class="index_name level2" >Заявки на перевозку</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ba3e_level0_row0" class="row_heading level0 row0" rowspan="2">ВТБ Калуга</th>
#       <th id="T_1ba3e_level1_row0" class="row_heading level1 row0" >Банкоматы</th>
#       <th id="T_1ba3e_level2_row0" class="row_heading level2 row0" >Заявки на перевозку 00859671 от 02.12.2025 17:21:44</th>
#       <td id="T_1ba3e_row0_col0" class="data row0 col0" > 1015262</td>
#     </tr>
#     <tr>
#       <th id="T_1ba3e_level1_row1" class="row_heading level1 row1" >Дверь-в-Дверь</th>
#       <th id="T_1ba3e_level2_row1" class="row_heading level2 row1" >Заявки на перевозку 00855377 от 06.11.2025 16:48:49</th>
#       <td id="T_1ba3e_row1_col0" class="data row1 col0" > 204562</td>
#     </tr>
#     <tr>
#       <th id="T_1ba3e_level0_row2" class="row_heading level0 row2" >Россельхозбанк</th>
#       <th id="T_1ba3e_level1_row2" class="row_heading level1 row2" >Банкоматы</th>
#       <th id="T_1ba3e_level2_row2" class="row_heading level2 row2" >Заявки на перевозку 00855309 от 06.11.2025 12:49:37</th>
#       <td id="T_1ba3e_row2_col0" class="data row2 col0" > 250917</td>
#     </tr>
#     <tr>
#       <th id="T_1ba3e_level0_row3" class="row_heading level0 row3" >All</th>
#       <th id="T_1ba3e_level1_row3" class="row_heading level1 row3" ></th>
#       <th id="T_1ba3e_level2_row3" class="row_heading level2 row3" ></th>
#       <td id="T_1ba3e_row3_col0" class="data row3 col0" > 1470741</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # TMS

# %% [markdown]
# ## load data

# %%
# run_data = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\Шипменты_группы_осн (XLSX).xlsx')

# %%
run_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\run (XLSX).xlsx")
run_carrier_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\run_carrier (XLSX).xlsx")
task_request_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\task_request (XLSX).xlsx")
request_sh_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\request_sh (XLSX).xlsx")
run_task_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\run_task (XLSX).xlsx")

# %%
run = run_data.copy()
run_carrier = run_carrier_data.copy()
task_request = task_request_data.copy()
request_sh = request_sh_data.copy()
run_task = run_task_data.copy()

# %%
run.head()
# Out:
#                                   Ссылка  \
# 0   Рейс 001034355 от 01.12.2023 0:23:39
# 1   Рейс 001034356 от 01.12.2023 7:42:21
# 2   Рейс 001034357 от 01.12.2023 7:43:52
# 3  Рейс 001034361 от 01.12.2023 10:14:50
# 4  Рейс 001034362 от 01.12.2023 10:16:09
#
#                              Вид перевозки Номер рейса  \
# 0                            Ж/д перевозка         NaN
# 1  Автоперевозка (Упрощенный путевой лист)         NaN
# 2  Автоперевозка (Упрощенный путевой лист)         NaN
# 3                            Автоперевозка         NaN
# 4                            Автоперевозка         NaN
#
#   Номер грузовой авианакладной  Вес AWBИтог
# 0                          NaN          NaN
# 1                          NaN          NaN
# 2                          NaN          NaN
# 3                          NaN          NaN
# 4                          NaN          NaN

# %%
run['Вид перевозки'].describe()
# Out:
# count             73323
# unique                6
# top       Автоперевозка
# freq              24922
# Name: Вид перевозки, dtype: object

# %%
run['Вид перевозки'].value_counts()
# Out:
# Вид перевозки
# Автоперевозка                                    24922
# Автоперевозка (Упрощенный путевой лист)          23716
# Авиаперевозка                                    13473
# Терминальная обработка (операции в аэропорту)    10936
# Ж/д перевозка                                      253
# Основная перевозка                                  23
# Name: count, dtype: int64

# %%
run_carrier.head()
# Out:
#                                     Рейс Перевозчик Контрагент  \
# 0  Рейс 000005553 от 14.10.2020 11:12:50        NaN        NaN
# 1  Рейс 001031125 от 31.10.2023 18:50:19        NaN        NaN
# 2  Рейс 001031127 от 31.10.2023 18:55:58        NaN        NaN
# 3  Рейс 001031128 от 31.10.2023 18:57:34        NaN        NaN
# 4  Рейс 001031129 от 31.10.2023 18:58:39        NaN        NaN
#
#   Тип транспортного средства              Транспортное средство
# 0                от 0,5 до 1   БМД_Моторс 287302 № Т 301 НМ 797
# 1                от 0,5 до 1  № А 617 АТ 977 БМД Моторс 287302
# 2              от 1т до 1,5т              № Н 967 АН 77 57503А
# 3                от 0,5 до 1         № А 562 АТ 977 ГАЗ A32R23
# 4                от 0,5 до 1        № Е 484 РЕ 799 Форд Транзит

# %%
run_carrier['Контрагент'].describe()
# Out:
# count                        47404
# unique                         103
# top       СФИНКС СЕКЬЮР ЛОДЖИСТИКС
# freq                         21569
# Name: Контрагент, dtype: object

# %%
run_carrier['Контрагент'].value_counts()
# Out:
# Контрагент
# СФИНКС СЕКЬЮР ЛОДЖИСТИКС         21569
# Аэрофлот                          3709
# Домодедово Карго Сервис Групп     3172
# Москва Карго (ГК Шереметьево)     2403
# ВНУКОВО-КАРГО                     1874
#                                  ...
# ИАТА                                 1
# Арт-Курьер                           1
# ФФ Карго Сервис                      1
# Лэнд Аэро ООО                        1
# СКАЙ ПАРТНЕР ЛОГИСТИКС ООО           1
# Name: count, Length: 103, dtype: int64

# %% [markdown]
# # temp save to pickle

# %%
folder_path = "P:\\Finance\\Finance\\FP&A\\scheduled_1C_reports\\"
ext_path = '.pkl'

# %%
run.to_pickle(folder_path + 'run' + ext_path)
run_carrier.to_pickle(folder_path + 'run_carrier' + ext_path)
task_request.to_pickle(folder_path + 'task_request' + ext_path)
request_sh.to_pickle(folder_path + 'request_sh' + ext_path)
run_task.to_pickle(folder_path + 'run_task' + ext_path)

# %%
sh.to_pickle(folder_path + 'sh' + ext_path)

# %%
run = pd.read_pickle(folder_path + 'run' + ext_path)
run_carrier = pd.read_pickle(folder_path + 'run_carrier' + ext_path)
task_request = pd.read_pickle(folder_path + 'task_request' + ext_path)
request_sh = pd.read_pickle(folder_path + 'request_sh' + ext_path)
run_task = pd.read_pickle(folder_path + 'run_task' + ext_path)

# %%
sh = pd.read_pickle(folder_path + 'sh' + ext_path)

# %%
sh.describe()
# Out:
#                        Дата доставки                     Дата сбора  \
# count                          25418                          25418
# mean   2025-08-27 01:13:06.375796736  2025-08-25 07:36:07.482886144
# min              2025-06-01 00:00:00            2025-04-01 00:00:00
# 25%              2025-07-15 00:00:00            2025-07-14 00:00:00
# 50%              2025-08-27 00:00:00            2025-08-26 00:00:00
# 75%              2025-10-08 00:00:00            2025-10-07 00:00:00
# max              2025-12-08 00:00:00            2025-12-04 17:00:00
# std                              NaN                            NaN
#
#        Номер авианакладной (HAWB)  Количество мест  Объем, м3  \
# count                2.541800e+04     25378.000000        0.0
# mean                 1.000001e+11         3.535621        NaN
# min                  1.000001e+11         1.000000        NaN
# 25%                  1.000001e+11         1.000000        NaN
# 50%                  1.000001e+11         1.000000        NaN
# 75%                  1.000002e+11         2.000000        NaN
# max                  1.000002e+11      4543.000000        NaN
# std                  7.484326e+03        32.653537        NaN
#
#        Объемный вес, кг  Оценочная стоимость, руб  Масса нетто, кг  \
# count               0.0              2.541800e+04       177.000000
# mean                NaN              5.800875e+07       359.125542
# min                 NaN              1.000000e+00         1.000000
# 25%                 NaN              5.000000e+05        24.261000
# 50%                 NaN              5.000000e+06        25.116000
# 75%                 NaN              2.842588e+07        48.800000
# max                 NaN              6.921900e+09     21000.000000
# std                 NaN              2.264635e+08      1729.986266
#
#        Масса брутто, кг  Сумма без НДС   Сумма с НДС  \
# count      25418.000000   2.528700e+04  2.528700e+04
# mean          79.735954   2.725298e+04  3.078183e+04
# min            0.010000   1.000000e-02  1.000000e-02
# 25%            1.000000   2.000000e+03  2.400000e+03
# 50%            3.000000   7.065000e+03  8.478000e+03
# 75%           15.000000   1.908772e+04  2.290526e+04
# max       131600.000000   4.389661e+06  5.267593e+06
# std         1114.964020   1.133891e+05  1.216622e+05
#
#        Оценочная стоимость, USD  Оценочная стоимость, EUR  \
# count              1.732000e+03              7.380000e+02
# mean               5.841854e+05              4.872942e+05
# min                1.000000e+02              8.000000e+01
# 25%                1.000000e+05              3.000000e+04
# 50%                2.500000e+05              1.000000e+05
# 75%                5.000000e+05              3.000000e+05
# max                3.893600e+07              3.000000e+07
# std                1.657368e+06              1.893859e+06
#
#        Оценочная стоимость, GBP  Оценочная стоимость, CNY  \
# count                 19.000000              7.680000e+02
# mean              149673.947368              3.191279e+06
# min                   20.000000              1.000000e+02
# 25%                 2807.500000              1.000000e+05
# 50%                 6000.000000              5.000000e+05
# 75%                17280.000000              2.000000e+06
# max              1000000.000000              5.000000e+07
# std               338943.514897              7.464385e+06
#
#        Оценочная стоимость, CHF  Оценочная стоимость, RUB  \
# count                  8.000000              2.326700e+04
# mean              183872.500000              5.671792e+07
# min                 5000.000000              1.000000e+00
# 25%                 8750.000000              5.000000e+05
# 50%                56490.000000              3.500000e+06
# 75%               229750.000000              2.337842e+07
# max               619000.000000              6.921900e+09
# std               270572.332645              2.296513e+08
#
#        Итоговая стоимость USD  Группа заявок
# count            2.541800e+04   1.030700e+04
# mean             7.830752e+05   1.573062e+05
# min              1.000000e-02   5.000000e+00
# 25%              6.346540e+03   2.103000e+03
# 50%              6.551356e+04   2.186000e+03
# 75%              3.808541e+05   1.515360e+05
# max              7.991074e+07   4.542031e+06
# std              3.027022e+06   6.165355e+05
