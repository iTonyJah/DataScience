# %%
import pandas as pd

# %%
sh_main_12m_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\sh_main_12m (XLSX).xlsx')

# %%
sh_main_3m_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\sh_main_3m (XLSX).xlsx')

# %%
sh3 = sh_main_3m_xlsx.copy()

# %%
sh = sh3

# %%
sh12 = sh_main_12m_xlsx.copy()

# %%
sh.shape
# Out:
# (23420, 46)

# %%
sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23420 entries, 0 to 23419
# Data columns (total 46 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Заявки на перевозку                        23420 non-null  object
#  1   ИНН, Заказчик                              23419 non-null  object
#  2   Статья движения денежных средств, Договор  23419 non-null  object
#  3   Грузоотправитель                           23419 non-null  object
#  4   Грузополучатель                            23419 non-null  object
#  5   Дата доставки                              23419 non-null  object
#  6   Дата сбора                                 23419 non-null  object
#  7   Адрес отправления                          23419 non-null  object
#  8   Адрес доставки                             23419 non-null  object
#  9   Город отправления                          23419 non-null  object
#  10  Город доставки                             23419 non-null  object
#  11  Вид перевозки                              23419 non-null  object
#  12  Номер авианакладной (HAWB)                 23419 non-null  float64
#  13  Вид транспорта                             23419 non-null  object
#  14  Организация                                23419 non-null  object
#  15  Информация о доставке                      7497 non-null   object
#  16  Комментарий для сбора и доставки           13582 non-null  object
#  17  Автор                                      23419 non-null  object
#  18  Дата создания                              23419 non-null  object
#  19  Контактное лицо отправителя                16264 non-null  object
#  20  Контактное лицо получателя                 19228 non-null  object
#  21  Грузоотправитель партнер                   23419 non-null  object
#  22  Грузополучатель партнер                    23419 non-null  object
#  23  Дата изменения                             23419 non-null  object
#  24  Изменил                                    23419 non-null  object
#  25  Ставка НДС                                 23419 non-null  object
#  26  Сумма включает НДС                         23419 non-null  object
#  27  Дата удаления                              23 non-null     object
#  28  Номер заявки клиента                       16852 non-null  object
#  29  Дата курса                                 23419 non-null  object
#  30  Количество мест                            23382 non-null  float64
#  31  Объем, м3                                  0 non-null      float64
#  32  Объемный вес, кг                           0 non-null      float64
#  33  Оценочная стоимость, руб                   23420 non-null  float64
#  34  Масса нетто, кг                            165 non-null    float64
#  35  Масса брутто, кг                           23420 non-null  float64
#  36  Сумма без НДС                              23326 non-null  float64
#  37  Сумма с НДС                                23326 non-null  float64
#  38  Оценочная стоимость, USD                   1577 non-null   float64
#  39  Оценочная стоимость, EUR                   686 non-null    float64
#  40  Оценочная стоимость, GBP                   18 non-null     float64
#  41  Оценочная стоимость, CNY                   692 non-null    float64
#  42  Оценочная стоимость, CHF                   5 non-null      float64
#  43  Оценочная стоимость, RUB                   21477 non-null  float64
#  44  Итоговая стоимость USD                     23420 non-null  float64
#  45  Группа заявок                              9666 non-null   float64
# dtypes: float64(17), object(29)
# memory usage: 8.2+ MB

# %%
if sh.iloc[-1,0] == 'Итого':
    print('drop Итого')
    sh.drop(sh.tail(1).index, inplace=True)
# Out:
# drop Итого

# %%
sh['Дата доставки'] = pd.to_datetime(sh['Дата доставки'], dayfirst=True, errors='coerce')
sh['Дата сбора'] = pd.to_datetime(sh['Дата сбора'], dayfirst=True, errors='coerce')
sh['period'] = sh['Дата доставки'].dt.strftime('%Y-%m')

# %%
sh[sh['Дата сбора'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Заявки на перевозку, ИНН, Заказчик, Статья движения денежных средств, Договор, Грузоотправитель, Грузополучатель, Дата доставки, Дата сбора, Адрес отправления, Адрес доставки, Город отправления, Город доставки, Вид перевозки, Номер авианакладной (HAWB), Вид транспорта, Организация, Информация о доставке, Комментарий для сбора и доставки, Автор, Дата создания, Контактное лицо отправителя, Контактное лицо получателя, Грузоотправитель партнер, Грузополучатель партнер, Дата изменения, Изменил, Ставка НДС, Сумма включает НДС, Дата удаления, Номер заявки клиента, Дата курса, Количество мест, Объем, м3, Объемный вес, кг, Оценочная стоимость, руб, Масса нетто, кг, Масса брутто, кг, Сумма без НДС, Сумма с НДС, Оценочная стоимость, USD, Оценочная стоимость, EUR, Оценочная стоимость, GBP, Оценочная стоимость, CNY, Оценочная стоимость, CHF, Оценочная стоимость, RUB, Итоговая стоимость USD, Группа заявок, period]
# Index: []
#
# [0 rows x 47 columns]

# %%
# пример исправления даты 'на лету'
# sh.loc[3354, 'Дата сбора'] = '23.08.2023'
# sh.loc[85076, 'Дата сбора'] = '29.04.2024'

# %%
sh[sh['Сумма без НДС'].isna() == True].count().tail()
# Out:
# Оценочная стоимость, CHF     0
# Оценочная стоимость, RUB    92
# Итоговая стоимость USD      94
# Группа заявок               53
# period                      94
# dtype: int64

# %%
sh.columns
# Out:
# Index(['Заявки на перевозку', 'ИНН, Заказчик',
#        'Статья движения денежных средств, Договор', 'Грузоотправитель',
#        'Грузополучатель', 'Дата доставки', 'Дата сбора', 'Адрес отправления',
#        'Адрес доставки', 'Город отправления', 'Город доставки',
#        'Вид перевозки', 'Номер авианакладной (HAWB)', 'Вид транспорта',
#        'Организация', 'Информация о доставке',
#        'Комментарий для сбора и доставки', 'Автор', 'Дата создания',
#        'Контактное лицо отправителя', 'Контактное лицо получателя',
#        'Грузоотправитель партнер', 'Грузополучатель партнер', 'Дата изменения',
#        'Изменил', 'Ставка НДС', 'Сумма включает НДС', 'Дата удаления',
#        'Номер заявки клиента', 'Дата курса', 'Количество мест', 'Объем, м3',
#        'Объемный вес, кг', 'Оценочная стоимость, руб', 'Масса нетто, кг',
#        'Масса брутто, кг', 'Сумма без НДС', 'Сумма с НДС',
#        'Оценочная стоимость, USD', 'Оценочная стоимость, EUR',
#        'Оценочная стоимость, GBP', 'Оценочная стоимость, CNY',
#        'Оценочная стоимость, CHF', 'Оценочная стоимость, RUB',
#        'Итоговая стоимость USD', 'Группа заявок', 'period'],
#       dtype='object')

# %%
sh = sh12.copy()

# %%
sh = sh3.copy()

# %%
sh3 = pd.read_pickle('sh3m.pkl')

# %%
sh12 = pd.read_pickle('sh12m.pkl')

# %%
sh12.shape, sh.shape
# Out:
# ((125713, 46), (23041, 47))

# %%
sh3 = sh.copy()

# %%
sh3.pivot_table(
    index = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4fff4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fff4_level0_col0" class="col_heading level0 col0" >Сумма без НДС</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fff4_level0_row0" class="row_heading level0 row0" >2025-06</th>
#       <td id="T_4fff4_row0_col0" class="data row0 col0" >100,361,210</td>
#     </tr>
#     <tr>
#       <th id="T_4fff4_level0_row1" class="row_heading level0 row1" >2025-07</th>
#       <td id="T_4fff4_row1_col0" class="data row1 col0" >114,716,506</td>
#     </tr>
#     <tr>
#       <th id="T_4fff4_level0_row2" class="row_heading level0 row2" >2025-08</th>
#       <td id="T_4fff4_row2_col0" class="data row2 col0" >109,443,171</td>
#     </tr>
#     <tr>
#       <th id="T_4fff4_level0_row3" class="row_heading level0 row3" >2025-09</th>
#       <td id="T_4fff4_row3_col0" class="data row3 col0" >124,588,751</td>
#     </tr>
#     <tr>
#       <th id="T_4fff4_level0_row4" class="row_heading level0 row4" >2025-10</th>
#       <td id="T_4fff4_row4_col0" class="data row4 col0" >150,628,539</td>
#     </tr>
#     <tr>
#       <th id="T_4fff4_level0_row5" class="row_heading level0 row5" >2025-11</th>
#       <td id="T_4fff4_row5_col0" class="data row5 col0" >20,090,395</td>
#     </tr>
#   </tbody>
# </table>

# %%
sh3.to_pickle('sh3m.pkl')

# %%
sh12 = sh.copy()

# %%
sh12.pivot_table(
    index = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_54ee8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54ee8_level0_col0" class="col_heading level0 col0" >Сумма без НДС</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54ee8_level0_row0" class="row_heading level0 row0" >2023-07</th>
#       <td id="T_54ee8_row0_col0" class="data row0 col0" >65,507,236</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row1" class="row_heading level0 row1" >2023-08</th>
#       <td id="T_54ee8_row1_col0" class="data row1 col0" >78,724,175</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row2" class="row_heading level0 row2" >2023-09</th>
#       <td id="T_54ee8_row2_col0" class="data row2 col0" >76,942,773</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row3" class="row_heading level0 row3" >2023-10</th>
#       <td id="T_54ee8_row3_col0" class="data row3 col0" >91,792,927</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row4" class="row_heading level0 row4" >2023-11</th>
#       <td id="T_54ee8_row4_col0" class="data row4 col0" >89,029,452</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row5" class="row_heading level0 row5" >2023-12</th>
#       <td id="T_54ee8_row5_col0" class="data row5 col0" >97,071,876</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row6" class="row_heading level0 row6" >2024-01</th>
#       <td id="T_54ee8_row6_col0" class="data row6 col0" >93,076,173</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row7" class="row_heading level0 row7" >2024-02</th>
#       <td id="T_54ee8_row7_col0" class="data row7 col0" >90,138,031</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row8" class="row_heading level0 row8" >2024-03</th>
#       <td id="T_54ee8_row8_col0" class="data row8 col0" >82,800,716</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row9" class="row_heading level0 row9" >2024-04</th>
#       <td id="T_54ee8_row9_col0" class="data row9 col0" >86,997,365</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row10" class="row_heading level0 row10" >2024-05</th>
#       <td id="T_54ee8_row10_col0" class="data row10 col0" >92,358,783</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row11" class="row_heading level0 row11" >2024-06</th>
#       <td id="T_54ee8_row11_col0" class="data row11 col0" >84,460,297</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row12" class="row_heading level0 row12" >2024-07</th>
#       <td id="T_54ee8_row12_col0" class="data row12 col0" >87,646,747</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row13" class="row_heading level0 row13" >2024-08</th>
#       <td id="T_54ee8_row13_col0" class="data row13 col0" >87,328,766</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row14" class="row_heading level0 row14" >2024-09</th>
#       <td id="T_54ee8_row14_col0" class="data row14 col0" >88,485,093</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row15" class="row_heading level0 row15" >2024-10</th>
#       <td id="T_54ee8_row15_col0" class="data row15 col0" >97,065,706</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row16" class="row_heading level0 row16" >2024-11</th>
#       <td id="T_54ee8_row16_col0" class="data row16 col0" >83,687,264</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row17" class="row_heading level0 row17" >2024-12</th>
#       <td id="T_54ee8_row17_col0" class="data row17 col0" >93,485,260</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row18" class="row_heading level0 row18" >2025-01</th>
#       <td id="T_54ee8_row18_col0" class="data row18 col0" >69,869,628</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row19" class="row_heading level0 row19" >2025-02</th>
#       <td id="T_54ee8_row19_col0" class="data row19 col0" >91,435,631</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row20" class="row_heading level0 row20" >2025-03</th>
#       <td id="T_54ee8_row20_col0" class="data row20 col0" >101,584,945</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row21" class="row_heading level0 row21" >2025-04</th>
#       <td id="T_54ee8_row21_col0" class="data row21 col0" >105,211,706</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row22" class="row_heading level0 row22" >2025-05</th>
#       <td id="T_54ee8_row22_col0" class="data row22 col0" >90,294,248</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row23" class="row_heading level0 row23" >2025-06</th>
#       <td id="T_54ee8_row23_col0" class="data row23 col0" >100,361,210</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row24" class="row_heading level0 row24" >2025-07</th>
#       <td id="T_54ee8_row24_col0" class="data row24 col0" >114,716,506</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row25" class="row_heading level0 row25" >2025-08</th>
#       <td id="T_54ee8_row25_col0" class="data row25 col0" >109,443,171</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row26" class="row_heading level0 row26" >2025-09</th>
#       <td id="T_54ee8_row26_col0" class="data row26 col0" >124,588,751</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row27" class="row_heading level0 row27" >2025-10</th>
#       <td id="T_54ee8_row27_col0" class="data row27 col0" >150,628,539</td>
#     </tr>
#     <tr>
#       <th id="T_54ee8_level0_row28" class="row_heading level0 row28" >2025-11</th>
#       <td id="T_54ee8_row28_col0" class="data row28 col0" >20,120,512</td>
#     </tr>
#   </tbody>
# </table>

# %%
sh12.to_pickle('sh12m.pkl')

# %%
import pandas as pd
sh12 = pd.read_pickle('sh12m.pkl')

# %%
sh = sh12.copy()

# %%
sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125832 entries, 0 to 125831
# Data columns (total 47 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Заявки на перевозку                        125832 non-null  object
#  1   ИНН, Заказчик                              125832 non-null  object
#  2   Статья движения денежных средств, Договор  125832 non-null  object
#  3   Грузоотправитель                           125832 non-null  object
#  4   Грузополучатель                            125832 non-null  object
#  5   Дата доставки                              125832 non-null  datetime64[ns]
#  6   Дата сбора                                 125832 non-null  datetime64[ns]
#  7   Адрес отправления                          125832 non-null  object
#  8   Адрес доставки                             125832 non-null  object
#  9   Город отправления                          125832 non-null  object
#  10  Город доставки                             125832 non-null  object
#  11  Вид перевозки                              125832 non-null  object
#  12  Номер авианакладной (HAWB)                 125832 non-null  float64
#  13  Вид транспорта                             125832 non-null  object
#  14  Организация                                125832 non-null  object
#  15  Информация о доставке                      35191 non-null   object
#  16  Комментарий для сбора и доставки           59860 non-null   object
#  17  Автор                                      125832 non-null  object
#  18  Дата создания                              125832 non-null  object
#  19  Контактное лицо отправителя                81070 non-null   object
#  20  Контактное лицо получателя                 88633 non-null   object
#  21  Грузоотправитель партнер                   125832 non-null  object
#  22  Грузополучатель партнер                    125832 non-null  object
#  23  Дата изменения                             125832 non-null  object
#  24  Изменил                                    125832 non-null  object
#  25  Ставка НДС                                 125793 non-null  object
#  26  Сумма включает НДС                         125832 non-null  object
#  27  Дата удаления                              114 non-null     object
#  28  Номер заявки клиента                       94567 non-null   object
#  29  Дата курса                                 125832 non-null  object
#  30  Количество мест                            125517 non-null  float64
#  31  Объем, м3                                  21 non-null      float64
#  32  Объемный вес, кг                           21 non-null      float64
#  33  Оценочная стоимость, руб                   125832 non-null  float64
#  34  Масса нетто, кг                            281 non-null     float64
#  35  Масса брутто, кг                           125832 non-null  float64
#  36  Сумма без НДС                              125735 non-null  float64
#  37  Сумма с НДС                                125735 non-null  float64
#  38  Оценочная стоимость, USD                   6156 non-null    float64
#  39  Оценочная стоимость, EUR                   2993 non-null    float64
#  40  Оценочная стоимость, GBP                   74 non-null      float64
#  41  Оценочная стоимость, CNY                   2346 non-null    float64
#  42  Оценочная стоимость, CHF                   45 non-null      float64
#  43  Оценочная стоимость, RUB                   117608 non-null  float64
#  44  Итоговая стоимость USD                     125797 non-null  float64
#  45  Группа заявок                              62919 non-null   float64
#  46  period                                     125832 non-null  object
# dtypes: datetime64[ns](2), float64(17), object(28)
# memory usage: 45.1+ MB

# %%
sh.describe()
# Out:
#                        Дата доставки                     Дата сбора  \
# count                         125832                         125832
# mean   2024-08-28 00:53:02.250619392  2024-08-26 05:04:36.977795840
# min              2023-07-01 00:00:00            2011-11-01 00:00:00
# 25%              2024-02-07 00:00:00            2024-02-06 00:00:00
# 50%              2024-08-08 00:00:00            2024-08-06 00:00:00
# 75%              2025-03-31 13:00:00            2025-03-31 00:00:00
# max              2025-11-28 00:00:00            2025-11-28 00:00:00
# std                              NaN                            NaN
#
#        Номер авианакладной (HAWB)  Количество мест  Объем, м3  \
# count                1.258320e+05    125517.000000  21.000000
# mean                 1.000001e+11         3.684194   0.128919
# min                  1.000000e+11         1.000000   0.000800
# 25%                  1.000001e+11         1.000000   0.040500
# 50%                  1.000001e+11         1.000000   0.136125
# 75%                  1.000001e+11         1.000000   0.136125
# max                  1.000002e+11      4582.000000   0.384160
# std                  3.712478e+04        30.103280   0.105894
#
#        Объемный вес, кг  Оценочная стоимость, руб  Масса нетто, кг  \
# count         21.000000              1.258320e+05       281.000000
# mean          21.529571              5.045494e+07       253.346758
# min            0.134000              1.000000e+00         0.900000
# 25%            6.764000              5.000000e+05         1.000000
# 50%           22.733000              3.000000e+06        24.068000
# 75%           22.733000              1.725030e+07        36.078000
# max           64.155000              9.000000e+09     21000.000000
# std           17.684141              2.510710e+08      1469.620219
#
#        Масса брутто, кг  Сумма без НДС   Сумма с НДС  \
# count     125832.000000   1.257350e+05  1.257350e+05
# mean          76.385934   2.103514e+04  2.382792e+04
# min            0.001000   1.000000e-02  1.000000e-02
# 25%            1.000000   1.350000e+03  1.620000e+03
# 50%            1.090000   4.550000e+03  5.460000e+03
# 75%           11.560750   1.470000e+04  1.764000e+04
# max       131600.000000   4.369848e+06  5.243818e+06
# std          859.987616   8.127705e+04  8.821195e+04
#
#        Оценочная стоимость, USD  Оценочная стоимость, EUR  \
# count              6.156000e+03              2.993000e+03
# mean               7.147958e+05              6.080863e+05
# min                5.000000e+00              1.000000e+00
# 25%                1.000000e+05              4.000000e+04
# 50%                2.217433e+05              1.000000e+05
# 75%                5.115000e+05              4.000000e+05
# max                6.500000e+07              3.000000e+07
# std                2.084608e+06              1.811041e+06
#
#        Оценочная стоимость, GBP  Оценочная стоимость, CNY  \
# count                 74.000000              2.346000e+03
# mean               64031.689189              3.728893e+06
# min                   10.000000              1.000000e+02
# 25%                  950.000000              1.000000e+05
# 50%                 4010.000000              6.000000e+05
# 75%                18842.500000              3.000000e+06
# max              1000000.000000              8.000000e+07
# std               189748.649123              8.545130e+06
#
#        Оценочная стоимость, CHF  Оценочная стоимость, RUB  \
# count              4.500000e+01              1.176080e+05
# mean               6.136786e+05              4.785972e+07
# min                1.000000e+01              1.000000e+00
# 25%                1.600000e+03              5.000000e+05
# 50%                1.000000e+04              2.350000e+06
# 75%                6.298000e+04              1.393266e+07
# max                5.546310e+06              9.000000e+09
# std                1.605228e+06              2.504512e+08
#
#        Итоговая стоимость USD  Группа заявок
# count            1.257970e+05   6.291900e+04
# mean             6.567319e+05   5.816010e+04
# min              1.000000e-02   9.000000e+00
# 25%              5.582080e+03   1.463000e+03
# 50%              3.649433e+04   1.691000e+03
# 75%              2.335400e+05   1.511830e+05
# max              1.460496e+08   4.542031e+06
# std              3.150160e+06   2.601794e+05
