# %% [markdown]
# # skip for a while

# %% [raw]
# sh_stat_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\Шипменты_группы_осн (XLSX).xlsx')

# %% [raw]
# sh_stat = sh_stat_xlsx.copy()

# %% [raw]
# sh_main_12m_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\sh_main_12m (XLSX).xlsx')

# %% [raw]
# sh12 = sh_main_12m_xlsx.copy()

# %% [markdown]
# # load main data

# %%
import pandas as pd

# %%
sh_main_3m_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\sh_main_3m (XLSX).xlsx')

# %%
sh3 = sh_main_3m_xlsx.copy()

sh = sh3

# %%
if sh.iloc[-1,0] == 'Итого':
    shTot = sh.iloc[-1,].loc['Сумма без НДС']
    print('drop Итого', shTot)
    sh.drop(sh.tail(1).index, inplace=True)
# Out:
# drop Итого 777733858.16

# %%
round(sh['Сумма без НДС'].sum(), 2) == shTot
# Out:
# True

# %%
sh[['ИНН', 'Заказчик']] = sh['ИНН, Заказчик'].str.split(', ', expand=True, n=1)
sh[['Статья движения денежных средств', 'Договор']] = sh['Статья движения денежных средств, Договор'].str.split(', ', expand=True, n=1)

# %%
sh['Дата доставки'] = pd.to_datetime(sh['Дата доставки'], dayfirst=True, errors='coerce')
sh['Дата сбора'] = pd.to_datetime(sh['Дата сбора'], dayfirst=True, errors='coerce')
sh['period'] = sh['Дата доставки'].dt.strftime('%Y-%m')

# %%
# пример исправления даты 'на лету'
# sh.loc[3354, 'Дата сбора'] = '23.08.2023'
# sh.loc[85076, 'Дата сбора'] = '29.04.2024'

# %%
sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29087 entries, 0 to 29086
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Заявки на перевозку                        29087 non-null  object
#  1   ИНН, Заказчик                              29087 non-null  object
#  2   Статья движения денежных средств, Договор  29087 non-null  object
#  3   Грузоотправитель                           29087 non-null  object
#  4   Грузополучатель                            29087 non-null  object
#  5   Дата доставки                              29087 non-null  datetime64[ns]
#  6   Дата сбора                                 29087 non-null  datetime64[ns]
#  7   Адрес отправления                          29087 non-null  object
#  8   Адрес доставки                             29087 non-null  object
#  9   Город отправления                          29087 non-null  object
#  10  Город доставки                             29087 non-null  object
#  11  Вид перевозки                              29087 non-null  object
#  12  Номер авианакладной (HAWB)                 29087 non-null  float64
#  13  Вид транспорта                             29087 non-null  object
#  14  Организация                                29087 non-null  object
#  15  Информация о доставке                      9279 non-null   object
#  16  Комментарий для сбора и доставки           16799 non-null  object
#  17  Автор                                      29087 non-null  object
#  18  Дата создания                              29087 non-null  object
#  19  Контактное лицо отправителя                20307 non-null  object
#  20  Контактное лицо получателя                 24043 non-null  object
#  21  Грузоотправитель партнер                   29087 non-null  object
#  22  Грузополучатель партнер                    29087 non-null  object
#  23  Дата изменения                             29087 non-null  object
#  24  Изменил                                    29087 non-null  object
#  25  Ставка НДС                                 29083 non-null  object
#  26  Сумма включает НДС                         29087 non-null  object
#  27  Дата удаления                              31 non-null     object
#  28  Номер заявки клиента                       20820 non-null  object
#  29  Дата курса                                 29087 non-null  object
#  30  Количество мест                            29039 non-null  float64
#  31  Объем, м3                                  0 non-null      float64
#  32  Объемный вес, кг                           0 non-null      float64
#  33  Оценочная стоимость, руб                   29087 non-null  float64
#  34  Масса нетто, кг                            191 non-null    float64
#  35  Масса брутто, кг                           29087 non-null  float64
#  36  Сумма без НДС                              28943 non-null  float64
#  37  Сумма с НДС                                28943 non-null  float64
#  38  Оценочная стоимость, USD                   2101 non-null   float64
#  39  Оценочная стоимость, EUR                   880 non-null    float64
#  40  Оценочная стоимость, GBP                   21 non-null     float64
#  41  Оценочная стоимость, CNY                   872 non-null    float64
#  42  Оценочная стоимость, CHF                   9 non-null      float64
#  43  Оценочная стоимость, RUB                   26466 non-null  float64
#  44  Итоговая стоимость USD                     29087 non-null  float64
#  45  Группа заявок                              11409 non-null  float64
#  46  ИНН                                        29087 non-null  object
#  47  Заказчик                                   29087 non-null  object
#  48  Статья движения денежных средств           29087 non-null  object
#  49  Договор                                    29087 non-null  object
#  50  period                                     29087 non-null  object
# dtypes: datetime64[ns](2), float64(17), object(32)
# memory usage: 11.3+ MB

# %%
sh[sh['Сумма без НДС'].isna() == True].count().tail()
# Out:
# ИНН                                 144
# Заказчик                            144
# Статья движения денежных средств    144
# Договор                             144
# period                              144
# dtype: int64

# %%
sh.pivot_table(
    index = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins = True,
).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2013">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2013_level0_col0" class="col_heading level0 col0" >Сумма без НДС</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2013_level0_row0" class="row_heading level0 row0" >2025-06</th>
#       <td id="T_f2013_row0_col0" class="data row0 col0" >100,361,210</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row1" class="row_heading level0 row1" >2025-07</th>
#       <td id="T_f2013_row1_col0" class="data row1 col0" >114,716,506</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row2" class="row_heading level0 row2" >2025-08</th>
#       <td id="T_f2013_row2_col0" class="data row2 col0" >109,443,171</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row3" class="row_heading level0 row3" >2025-09</th>
#       <td id="T_f2013_row3_col0" class="data row3 col0" >124,588,751</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row4" class="row_heading level0 row4" >2025-10</th>
#       <td id="T_f2013_row4_col0" class="data row4 col0" >154,441,667</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row5" class="row_heading level0 row5" >2025-11</th>
#       <td id="T_f2013_row5_col0" class="data row5 col0" >106,509,946</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row6" class="row_heading level0 row6" >2025-12</th>
#       <td id="T_f2013_row6_col0" class="data row6 col0" >67,659,225</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row7" class="row_heading level0 row7" >2026-01</th>
#       <td id="T_f2013_row7_col0" class="data row7 col0" >13,382</td>
#     </tr>
#     <tr>
#       <th id="T_f2013_level0_row8" class="row_heading level0 row8" >All</th>
#       <td id="T_f2013_row8_col0" class="data row8 col0" >777,733,858</td>
#     </tr>
#   </tbody>
# </table>

# %%
city = 'Астрахань'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
city = 'Волгоград'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
city = 'Воронеж'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
city = 'Калуга'
region = (sh['Город отправления'] == city) & (sh['Город доставки'] == city)

# %%
sh_reg = sh[region]

# %%
sh_reg.pivot_table(
    index = ['Заказчик', 'Вид перевозки'],
    columns = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins = True,
).style.format("{: .0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a463e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >period</th>
#       <th id="T_a463e_level0_col0" class="col_heading level0 col0" >2025-06</th>
#       <th id="T_a463e_level0_col1" class="col_heading level0 col1" >2025-07</th>
#       <th id="T_a463e_level0_col2" class="col_heading level0 col2" >2025-08</th>
#       <th id="T_a463e_level0_col3" class="col_heading level0 col3" >2025-09</th>
#       <th id="T_a463e_level0_col4" class="col_heading level0 col4" >2025-10</th>
#       <th id="T_a463e_level0_col5" class="col_heading level0 col5" >2025-11</th>
#       <th id="T_a463e_level0_col6" class="col_heading level0 col6" >2025-12</th>
#       <th id="T_a463e_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Заказчик</th>
#       <th class="index_name level1" >Вид перевозки</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a463e_level0_row0" class="row_heading level0 row0" rowspan="2">ВТБ Калуга</th>
#       <th id="T_a463e_level1_row0" class="row_heading level1 row0" >Банкоматы</th>
#       <td id="T_a463e_row0_col0" class="data row0 col0" > 800065</td>
#       <td id="T_a463e_row0_col1" class="data row0 col1" > 877542</td>
#       <td id="T_a463e_row0_col2" class="data row0 col2" > 1063532</td>
#       <td id="T_a463e_row0_col3" class="data row0 col3" > 944544</td>
#       <td id="T_a463e_row0_col4" class="data row0 col4" > 1015262</td>
#       <td id="T_a463e_row0_col5" class="data row0 col5" > 1015262</td>
#       <td id="T_a463e_row0_col6" class="data row0 col6" > nan</td>
#       <td id="T_a463e_row0_col7" class="data row0 col7" > 5716208</td>
#     </tr>
#     <tr>
#       <th id="T_a463e_level1_row1" class="row_heading level1 row1" >Дверь-в-Дверь</th>
#       <td id="T_a463e_row1_col0" class="data row1 col0" > nan</td>
#       <td id="T_a463e_row1_col1" class="data row1 col1" > nan</td>
#       <td id="T_a463e_row1_col2" class="data row1 col2" > nan</td>
#       <td id="T_a463e_row1_col3" class="data row1 col3" > nan</td>
#       <td id="T_a463e_row1_col4" class="data row1 col4" > 206627</td>
#       <td id="T_a463e_row1_col5" class="data row1 col5" > 204562</td>
#       <td id="T_a463e_row1_col6" class="data row1 col6" > 204562</td>
#       <td id="T_a463e_row1_col7" class="data row1 col7" > 615751</td>
#     </tr>
#     <tr>
#       <th id="T_a463e_level0_row2" class="row_heading level0 row2" >Россельхозбанк</th>
#       <th id="T_a463e_level1_row2" class="row_heading level1 row2" >Банкоматы</th>
#       <td id="T_a463e_row2_col0" class="data row2 col0" > 278250</td>
#       <td id="T_a463e_row2_col1" class="data row2 col1" > 243000</td>
#       <td id="T_a463e_row2_col2" class="data row2 col2" > 279833</td>
#       <td id="T_a463e_row2_col3" class="data row2 col3" > 253500</td>
#       <td id="T_a463e_row2_col4" class="data row2 col4" > 235667</td>
#       <td id="T_a463e_row2_col5" class="data row2 col5" > 250917</td>
#       <td id="T_a463e_row2_col6" class="data row2 col6" > 230000</td>
#       <td id="T_a463e_row2_col7" class="data row2 col7" > 1771167</td>
#     </tr>
#     <tr>
#       <th id="T_a463e_level0_row3" class="row_heading level0 row3" >All</th>
#       <th id="T_a463e_level1_row3" class="row_heading level1 row3" ></th>
#       <td id="T_a463e_row3_col0" class="data row3 col0" > 1078315</td>
#       <td id="T_a463e_row3_col1" class="data row3 col1" > 1120542</td>
#       <td id="T_a463e_row3_col2" class="data row3 col2" > 1343366</td>
#       <td id="T_a463e_row3_col3" class="data row3 col3" > 1198044</td>
#       <td id="T_a463e_row3_col4" class="data row3 col4" > 1457556</td>
#       <td id="T_a463e_row3_col5" class="data row3 col5" > 1470741</td>
#       <td id="T_a463e_row3_col6" class="data row3 col6" > 434562</td>
#       <td id="T_a463e_row3_col7" class="data row3 col7" > 8103126</td>
#     </tr>
#   </tbody>
# </table>

# %%
sh_reg.pivot_table(
    index = ['Заказчик'],
    columns = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins=True,
).style.format("{:.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_31ce7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th id="T_31ce7_level0_col0" class="col_heading level0 col0" >2025-06</th>
#       <th id="T_31ce7_level0_col1" class="col_heading level0 col1" >2025-07</th>
#       <th id="T_31ce7_level0_col2" class="col_heading level0 col2" >2025-08</th>
#       <th id="T_31ce7_level0_col3" class="col_heading level0 col3" >2025-09</th>
#       <th id="T_31ce7_level0_col4" class="col_heading level0 col4" >2025-10</th>
#       <th id="T_31ce7_level0_col5" class="col_heading level0 col5" >2025-11</th>
#       <th id="T_31ce7_level0_col6" class="col_heading level0 col6" >2025-12</th>
#       <th id="T_31ce7_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Заказчик</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31ce7_level0_row0" class="row_heading level0 row0" >ВТБ Калуга</th>
#       <td id="T_31ce7_row0_col0" class="data row0 col0" >800065</td>
#       <td id="T_31ce7_row0_col1" class="data row0 col1" >877542</td>
#       <td id="T_31ce7_row0_col2" class="data row0 col2" >1063532</td>
#       <td id="T_31ce7_row0_col3" class="data row0 col3" >944544</td>
#       <td id="T_31ce7_row0_col4" class="data row0 col4" >1221890</td>
#       <td id="T_31ce7_row0_col5" class="data row0 col5" >1219824</td>
#       <td id="T_31ce7_row0_col6" class="data row0 col6" >204562</td>
#       <td id="T_31ce7_row0_col7" class="data row0 col7" >6331959</td>
#     </tr>
#     <tr>
#       <th id="T_31ce7_level0_row1" class="row_heading level0 row1" >Россельхозбанк</th>
#       <td id="T_31ce7_row1_col0" class="data row1 col0" >278250</td>
#       <td id="T_31ce7_row1_col1" class="data row1 col1" >243000</td>
#       <td id="T_31ce7_row1_col2" class="data row1 col2" >279833</td>
#       <td id="T_31ce7_row1_col3" class="data row1 col3" >253500</td>
#       <td id="T_31ce7_row1_col4" class="data row1 col4" >235667</td>
#       <td id="T_31ce7_row1_col5" class="data row1 col5" >250917</td>
#       <td id="T_31ce7_row1_col6" class="data row1 col6" >230000</td>
#       <td id="T_31ce7_row1_col7" class="data row1 col7" >1771167</td>
#     </tr>
#     <tr>
#       <th id="T_31ce7_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_31ce7_row2_col0" class="data row2 col0" >1078315</td>
#       <td id="T_31ce7_row2_col1" class="data row2 col1" >1120542</td>
#       <td id="T_31ce7_row2_col2" class="data row2 col2" >1343366</td>
#       <td id="T_31ce7_row2_col3" class="data row2 col3" >1198044</td>
#       <td id="T_31ce7_row2_col4" class="data row2 col4" >1457556</td>
#       <td id="T_31ce7_row2_col5" class="data row2 col5" >1470741</td>
#       <td id="T_31ce7_row2_col6" class="data row2 col6" >434562</td>
#       <td id="T_31ce7_row2_col7" class="data row2 col7" >8103126</td>
#     </tr>
#   </tbody>
# </table>

# %%
period = '2025-11'

# %%
sh_reg.period.describe()
# Out:
# count          16
# unique          7
# top       2025-10
# freq            3
# Name: period, dtype: object

# %%
sh_reg[sh_reg['period']==period].pivot_table(
    index = ['Заказчик', 'Вид перевозки', 'Заявки на перевозку',],
    columns = 'period',
    values = 'Сумма без НДС',
    aggfunc = 'sum',
    margins = True,
).drop('All', axis=1).style.format("{: .0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_00fef">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >period</th>
#       <th id="T_00fef_level0_col0" class="col_heading level0 col0" >2025-11</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Заказчик</th>
#       <th class="index_name level1" >Вид перевозки</th>
#       <th class="index_name level2" >Заявки на перевозку</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00fef_level0_row0" class="row_heading level0 row0" rowspan="2">ВТБ Калуга</th>
#       <th id="T_00fef_level1_row0" class="row_heading level1 row0" >Банкоматы</th>
#       <th id="T_00fef_level2_row0" class="row_heading level2 row0" >Заявки на перевозку 00859671 от 02.12.2025 17:21:44</th>
#       <td id="T_00fef_row0_col0" class="data row0 col0" > 1015262</td>
#     </tr>
#     <tr>
#       <th id="T_00fef_level1_row1" class="row_heading level1 row1" >Дверь-в-Дверь</th>
#       <th id="T_00fef_level2_row1" class="row_heading level2 row1" >Заявки на перевозку 00855377 от 06.11.2025 16:48:49</th>
#       <td id="T_00fef_row1_col0" class="data row1 col0" > 204562</td>
#     </tr>
#     <tr>
#       <th id="T_00fef_level0_row2" class="row_heading level0 row2" >Россельхозбанк</th>
#       <th id="T_00fef_level1_row2" class="row_heading level1 row2" >Банкоматы</th>
#       <th id="T_00fef_level2_row2" class="row_heading level2 row2" >Заявки на перевозку 00855309 от 06.11.2025 12:49:37</th>
#       <td id="T_00fef_row2_col0" class="data row2 col0" > 250917</td>
#     </tr>
#     <tr>
#       <th id="T_00fef_level0_row3" class="row_heading level0 row3" >All</th>
#       <th id="T_00fef_level1_row3" class="row_heading level1 row3" ></th>
#       <th id="T_00fef_level2_row3" class="row_heading level2 row3" ></th>
#       <td id="T_00fef_row3_col0" class="data row3 col0" > 1470741</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # TMS

# %% [markdown]
# ## load data

# %%
# run_data = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\Шипменты_группы_осн (XLSX).xlsx')

# %%
run_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\run (XLSX).xlsx")
run_carrier_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\run_carrier (XLSX).xlsx")
task_request_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\task_request (XLSX).xlsx")
request_sh_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\request_sh (XLSX).xlsx")
run_task_data = pd.read_excel(r"P:\Finance\Finance\FP&A\scheduled_1C_reports\run_task (XLSX).xlsx")

# %%
run = run_data.copy()
run_carrier = run_carrier_data.copy()
task_request = task_request_data.copy()
request_sh = request_sh_data.copy()
run_task = run_task_data.copy()

# %%
run.head()
# Out:
#                                   Ссылка  \
# 0   Рейс 001034355 от 01.12.2023 0:23:39
# 1   Рейс 001034356 от 01.12.2023 7:42:21
# 2   Рейс 001034357 от 01.12.2023 7:43:52
# 3  Рейс 001034361 от 01.12.2023 10:14:50
# 4  Рейс 001034362 от 01.12.2023 10:16:09
#
#                              Вид перевозки Номер рейса  \
# 0                            Ж/д перевозка         NaN
# 1  Автоперевозка (Упрощенный путевой лист)         NaN
# 2  Автоперевозка (Упрощенный путевой лист)         NaN
# 3                            Автоперевозка         NaN
# 4                            Автоперевозка         NaN
#
#   Номер грузовой авианакладной  Вес AWBИтог
# 0                          NaN          NaN
# 1                          NaN          NaN
# 2                          NaN          NaN
# 3                          NaN          NaN
# 4                          NaN          NaN

# %%
run['Вид перевозки'].describe()
# Out:
# count             73920
# unique                6
# top       Автоперевозка
# freq              25053
# Name: Вид перевозки, dtype: object

# %%
run['Вид перевозки'].value_counts()
# Out:
# Вид перевозки
# Автоперевозка                                    25053
# Автоперевозка (Упрощенный путевой лист)          23969
# Авиаперевозка                                    13599
# Терминальная обработка (операции в аэропорту)    11021
# Ж/д перевозка                                      255
# Основная перевозка                                  23
# Name: count, dtype: int64

# %%
run_carrier.head()
# Out:
#                                     Рейс Перевозчик Контрагент  \
# 0  Рейс 000005553 от 14.10.2020 11:12:50        NaN        NaN
# 1  Рейс 001031125 от 31.10.2023 18:50:19        NaN        NaN
# 2  Рейс 001031127 от 31.10.2023 18:55:58        NaN        NaN
# 3  Рейс 001031128 от 31.10.2023 18:57:34        NaN        NaN
# 4  Рейс 001031129 от 31.10.2023 18:58:39        NaN        NaN
#
#   Тип транспортного средства              Транспортное средство
# 0                от 0,5 до 1   БМД_Моторс 287302 № Т 301 НМ 797
# 1                от 0,5 до 1  № А 617 АТ 977 БМД Моторс 287302
# 2              от 1т до 1,5т              № Н 967 АН 77 57503А
# 3                от 0,5 до 1         № А 562 АТ 977 ГАЗ A32R23
# 4                от 0,5 до 1        № Е 484 РЕ 799 Форд Транзит

# %%
run_carrier['Контрагент'].describe()
# Out:
# count                        47727
# unique                         103
# top       СФИНКС СЕКЬЮР ЛОДЖИСТИКС
# freq                         21671
# Name: Контрагент, dtype: object

# %%
run_carrier['Контрагент'].value_counts()
# Out:
# Контрагент
# СФИНКС СЕКЬЮР ЛОДЖИСТИКС         21671
# Аэрофлот                          3754
# Домодедово Карго Сервис Групп     3194
# Москва Карго (ГК Шереметьево)     2428
# ВНУКОВО-КАРГО                     1886
#                                  ...
# САВО ООО                             1
# ЕТК                                  1
# Дельта-Карго Шипинг Сервис           1
# Петролеум Аналистс АО                1
# ИАТА                                 1
# Name: count, Length: 103, dtype: int64

# %% [markdown]
# # temp save to pickle

# %%
folder_path = "P:\\Finance\\Finance\\FP&A\\scheduled_1C_reports\\"
ext_path = '.pkl'

# %%
run.to_pickle(folder_path + 'run' + ext_path)
run_carrier.to_pickle(folder_path + 'run_carrier' + ext_path)
task_request.to_pickle(folder_path + 'task_request' + ext_path)
request_sh.to_pickle(folder_path + 'request_sh' + ext_path)
run_task.to_pickle(folder_path + 'run_task' + ext_path)

# %%
sh.to_pickle(folder_path + 'sh' + ext_path)

# %%
run = pd.read_pickle(folder_path + 'run' + ext_path)
run_carrier = pd.read_pickle(folder_path + 'run_carrier' + ext_path)
task_request = pd.read_pickle(folder_path + 'task_request' + ext_path)
request_sh = pd.read_pickle(folder_path + 'request_sh' + ext_path)
run_task = pd.read_pickle(folder_path + 'run_task' + ext_path)

# %%
sh = pd.read_pickle(folder_path + 'sh' + ext_path)

# %%
sh.describe()
# Out:
#                        Дата доставки                     Дата сбора  \
# count                          29087                          29087
# mean   2025-09-08 12:48:34.446316288  2025-09-06 19:20:36.960841472
# min              2025-06-01 00:00:00            2025-04-01 00:00:00
# 25%              2025-07-21 00:00:00            2025-07-18 00:00:00
# 50%              2025-09-09 00:00:00            2025-09-08 00:00:00
# 75%              2025-10-28 00:00:00            2025-10-27 00:00:00
# max              2026-01-10 00:00:00            2025-12-30 00:00:00
# std                              NaN                            NaN
#
#        Номер авианакладной (HAWB)  Количество мест  Объем, м3  \
# count                2.908700e+04     29039.000000        0.0
# mean                 1.000001e+11         3.556803        NaN
# min                  1.000001e+11         1.000000        NaN
# 25%                  1.000001e+11         1.000000        NaN
# 50%                  1.000001e+11         1.000000        NaN
# 75%                  1.000002e+11         2.000000        NaN
# max                  1.000002e+11      4543.000000        NaN
# std                  8.576229e+03        31.209954        NaN
#
#        Объемный вес, кг  Оценочная стоимость, руб  Масса нетто, кг  \
# count               0.0              2.908700e+04       191.000000
# mean                NaN              5.919530e+07       347.044387
# min                 NaN              1.000000e+00         1.000000
# 25%                 NaN              5.000000e+05        24.219000
# 50%                 NaN              5.002002e+06        25.089000
# 75%                 NaN              2.850000e+07        48.739000
# max                 NaN              6.921900e+09     21000.000000
# std                 NaN              2.402482e+08      1674.323731
#
#        Масса брутто, кг  Сумма без НДС   Сумма с НДС  \
# count      29087.000000   2.894300e+04  2.894300e+04
# mean          77.947898   2.687122e+04  3.036669e+04
# min            0.010000   1.000000e-02  1.000000e-02
# 25%            1.000000   2.000000e+03  2.400000e+03
# 50%            3.000000   7.065000e+03  8.478000e+03
# 75%           14.960000   1.890000e+04  2.268000e+04
# max       131600.000000   4.389661e+06  5.267593e+06
# std         1049.201015   1.135029e+05  1.215153e+05
#
#        Оценочная стоимость, USD  Оценочная стоимость, EUR  \
# count              2.101000e+03              8.800000e+02
# mean               7.186973e+05              6.238824e+05
# min                1.000000e+02              8.000000e+01
# 25%                1.000000e+05              3.000000e+04
# 50%                2.500000e+05              1.000000e+05
# 75%                5.000000e+05              3.000000e+05
# max                5.000000e+07              6.900000e+07
# std                2.714768e+06              3.728400e+06
#
#        Оценочная стоимость, GBP  Оценочная стоимость, CNY  \
# count                 21.000000              8.720000e+02
# mean              135449.761905              3.244263e+06
# min                   20.000000              1.000000e+02
# 25%                 2000.000000              1.000000e+05
# 50%                 5000.000000              5.000000e+05
# 75%                14560.000000              2.000000e+06
# max              1000000.000000              5.000000e+07
# std               324673.154551              7.641790e+06
#
#        Оценочная стоимость, CHF  Оценочная стоимость, RUB  \
# count                  9.000000              2.646600e+04
# mean              165108.888889              5.679750e+07
# min                 5000.000000              1.000000e+00
# 25%                10000.000000              5.000000e+05
# 50%                50000.000000              3.500000e+06
# 75%               100000.000000              2.301378e+07
# max               619000.000000              6.921900e+09
# std               259281.452694              2.337519e+08
#
#        Итоговая стоимость USD  Группа заявок
# count            2.908700e+04   1.140900e+04
# mean             8.007350e+05   1.423255e+05
# min              1.000000e-02   5.000000e+00
# 25%              6.369670e+03   2.111000e+03
# 50%              6.638695e+04   2.208000e+03
# 75%              3.836234e+05   1.515270e+05
# max              8.620266e+07   4.542031e+06
# std              3.231504e+06   5.877894e+05

# %% [markdown]
# # Payroll

# %%
sh_main_3m_xlsx = pd.read_excel(r'P:\Finance\Finance\FP&A\scheduled_1C_reports\sh_main_3m (XLSX).xlsx')

# %%
# Укажите путь к файлу и имя нужного листа
file_path = 'C:\OneDrive\Documents\BGS model\Budget\Workings 2025\ЗП_2025.xlsx'
sheet_name = 'data' # или 'Лист1', 'Sheet2' и т.д.

payroll_data = pd.read_excel(file_path, sheet_name=sheet_name)
payroll = payroll_data.copy()

# %%
# Теперь df содержит данные только с "НазваниеЛиста"
payroll.head(2)
# Out:
#       Период                   Подразделение                  Сотрудник  \
# 0 2023-09-30  Департамент спецавтотранспорта  Алексеев Сергей Сергеевич
# 1 2023-09-30  Департамент спецавтотранспорта   Беликов Сергей Сергеевич
#
#   Тип начисления  Value   HC  \
# 0         Отр.Дн   21.0  0.0
# 1         Отр.Дн   21.0  0.0
#
#               Подразделение с агентами и исключениям  \
# 0  Департамент развития и контроля региональной л...
# 1                     Департамент спецавтотранспорта
#
#                              City Exp       Region       cost_account  \
# 0  _Департамент региональных операций   _Москва_ЦО  6000_20 _Indirect
# 1           _Москва Спецавтотранспорт  _Москва_33б      6000_25_Admin
#
#           Должность  Выбор Тип.круп.    Тип.инд
# 0  Начальник отдела  False  Дни_Часы  00_Отр.Дн
# 1   Старший механик  False  Дни_Часы  00_Отр.Дн
